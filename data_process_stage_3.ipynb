# %%
import os
import pandas as pd

# Directory containing the CSV files
directory = 'draft-final-data-2'

# Dictionary to store the DataFrames
weather_stations = {}

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        # Read the CSV file into a DataFrame
        filepath = os.path.join(directory, filename)
        df = pd.read_csv(filepath)
        
        # Store the DataFrame in the dictionary
        weather_stations[int(filename[:-4])] = df

# Display the keys of the dictionary to verify
print(weather_stations.keys())
# Out:
# dict_keys([72790024141, 72785524114, 72789094197, 72793024233, 72785794129, 72788594266, 72797624217, 72785024157, 72797094240, 72798594276, 72792424223, 72792894263, 72781024243, 72781524237, 72788324220, 72698824219, 72793894274, 74206024207, 72782724110, 72793724222, 72792594227, 72782594239, 72794504205, 72792394225, 72784524163, 72792024227, 72785694176])

# %%
# Pick one dataframe from the dictionary
sample_df = weather_stations[72790024141]

# Show the column names and their data types
print(sample_df.dtypes)
# Out:
# DATE                         object
# STATION                       int64
# DailyAltimeterSetting       float64
# DailyDewPointTemperature    float64
# DailyDryBulbTemperature     float64
# DailyPrecipitation          float64
# DailyPresentWeatherType      object
# DailyPressureChange         float64
# DailyPressureTendency       float64
# DailyRelativeHumidity       float64
# DailySeaLevelPressure       float64
# DailySkyConditions           object
# DailyStationPressure        float64
# DailyWetBulbTemperature     float64
# DailyWindDirection           object
# DailyWindSpeed              float64
# dtype: object

# %%
# Create a copy of the dictionary
weather_stations_trim = {key: df.copy() for key, df in weather_stations.items()}

# Drop the specified columns from the copied dictionary
for key in weather_stations_trim:
    weather_stations_trim[key] = weather_stations_trim[key].drop(columns=['STATION', 'DATE'])

# Verify the columns have been dropped
sample_df = weather_stations_trim[72790024141]
print(sample_df.dtypes)
# Out:
# DailyAltimeterSetting       float64
# DailyDewPointTemperature    float64
# DailyDryBulbTemperature     float64
# DailyPrecipitation          float64
# DailyPresentWeatherType      object
# DailyPressureChange         float64
# DailyPressureTendency       float64
# DailyRelativeHumidity       float64
# DailySeaLevelPressure       float64
# DailySkyConditions           object
# DailyStationPressure        float64
# DailyWetBulbTemperature     float64
# DailyWindDirection           object
# DailyWindSpeed              float64
# dtype: object

# %%
# Initialize sets to store unique values
unique_precipitation = set()
unique_weather_type = set()
unique_sky_conditions = set()
unique_wind_direction = set()

# Iterate through each dataframe in the dictionary
for key, df in weather_stations_trim.items():
    unique_precipitation.update(df['DailyPrecipitation'].unique())
    unique_weather_type.update(df['DailyPresentWeatherType'].unique())
    unique_sky_conditions.update(df['DailySkyConditions'].unique())
    unique_wind_direction.update(df['DailyWindDirection'].unique())

# Convert sets to lists for better readability
unique_precipitation = list(unique_precipitation)
unique_weather_type = list(unique_weather_type)
unique_sky_conditions = list(unique_sky_conditions)
unique_wind_direction = list(unique_wind_direction)

# Display the unique values
print("Unique DailyPrecipitation:", unique_precipitation)
print("Unique DailyPresentWeatherType:", unique_weather_type)
print("Unique DailySkyConditions:", unique_sky_conditions)
print("Unique DailyWindDirection:", unique_wind_direction)
# Out:
# Unique DailyPrecipitation: [0.0, 0.015625, 0.03125, 0.01953125, 0.01171875, 0.0078125, 0.00390625, 0.0378947368421052, 0.078125, 0.0625, 0.0546875, 0.0201190476190476, 0.0282499999999999, 0.0469354838709677, 0.0271111111111111, 0.0001219512195121, 0.0035185185185185, 0.0134821428571428, 0.0255813953488371, 0.0157317073170731, 0.0372413793103448, 0.0179761904761904, 0.0144594594594594, 0.0204651162790697, 0.0001136363636363, 0.015735294117647, 0.0188333333333333, 0.0626136363636363, 0.0583898305084745, 0.0313636363636363, 0.0014492753623188, 0.0258695652173913, 0.007037037037037, 0.0205128205128205, 0.0157575757575757, 0.0021739130434782, 0.0119827586206896, 0.0107, 0.0105555555555555, 0.0121153846153846, 0.0376666666666666, 0.0001515151515151, 0.0063207547169811, 9.80392156862745e-05, 0.0322368421052631, 0.014074074074074, 0.0056756756756756, 0.0132653061224489, 0.0132894736842105, 0.0001612903225806, 0.0280434782608695, 0.0306976744186046, 0.0157954545454545, 0.0470454545454545, 0.0281395348837209, 0.0175925925925925, 0.0470967741935483, 0.0001470588235294, 0.0564999999999999, 0.0429824561403508, 0.0001960784313725, 0.0002439024390243, 0.0214, 0.0158064516129032, 0.0158536585365853, 0.0242307692307692, 0.0269642857142857, 0.0002083333333333, 0.0158333333333333, 0.0314583333333333, 0.0158823529411764, 0.1539189189189189, 0.0074358974358974, 0.0002272727272727, 0.0627272727272727, 0.011551724137931, 0.0193518518518518, 0.020969387755102, 0.0311702127659574, 0.0075555555555555, 0.026578947368421, 0.0076315789473684, 0.0245744680851063, 0.0172826086956521, 0.0346666666666666, 0.0003225806451612, 0.0111224489795918, 0.000340909090909, 0.0265254237288135, 0.031590909090909, 0.0263888888888888, 0.0201351351351351, 0.02525, 0.0159677419354838, 0.0211111111111111, 0.0089795918367346, 0.0002941176470588, 0.0378749999999999, 0.0159848484848484, 0.0003658536585365, 0.0159090909090909, 0.0184, 0.0111538461538461, 0.0345945945945945, 0.0253636363636363, 0.0128333333333333, 0.0315853658536585, 0.0003030303030303, 0.0316129032258064, 0.0471951219512195, 0.0834210526315789, 0.0160294117647058, 0.0113513513513513, 0.0065217391304347, 0.0160227272727272, 0.0056849315068493, 0.0472727272727272, 0.0226785714285714, 0.0539285714285714, 0.0045555555555555, 0.011547619047619, 0.0179787234042553, 0.0004166666666666, 0.0316666666666666, 0.0238541666666666, 0.0472916666666666, 0.0160416666666666, 0.0106896551724137, 0.0857692307692307, 0.0916, 0.0205357142857142, 0.0232692307692307, 0.0351851851851851, 0.0535, 0.006625, 0.0057627118644067, 0.0181111111111111, 0.0036249999999999, 0.0004545454545454, 0.023103448275862, 0.0652112676056337, 0.0154, 0.0004411764705882, 0.0152631578947368, 0.0588157894736842, 0.0098333333333333, 0.0398, 0.0353846153846153, 0.0041346153846153, 0.0056944444444444, 0.0004838709677419, 0.0161764705882352, 0.0355172413793103, 0.0015555555555555, 0.0258108108108108, 0.0286666666666666, 0.0094047619047619, 0.0317647058823529, 0.0101923076923076, 0.0161290322580645, 0.0294067796610169, 0.071195652173913, 0.0183928571428571, 0.0496428571428571, 0.0017948717948717, 0.0252830188679245, 0.0439814814814814, 0.0479310344827586, 0.008695652173913, 0.0072619047619047, 0.0105737704918032, 0.01925, 0.003625, 0.0072033898305084, 0.0505, 0.063030303030303, 0.0162499999999999, 0.0096052631578947, 0.0124, 0.0006097560975609, 0.0109722222222222, 0.0397959183673469, 0.0422222222222222, 0.0005882352941176, 0.0093999999999999, 0.0101449275362318, 0.0068333333333333, 0.0867567567567567, 0.0006451612903225, 0.0314864864864864, 0.0599137931034482, 0.0162121212121212, 0.0350862068965517, 0.0492592592592592, 0.0626153846153846, 0.0006818181818181, 0.0082432432432432, 0.0006060606060606, 0.0319117647058823, 0.0083018867924528, 0.0098275862068965, 0.0475757575757575, 0.0228947368421052, 0.0039473684210526, 0.000625, 0.00453125, 0.01625, 0.01234375, 0.03578125, 0.0084375, 0.0475, 0.031875, 0.04359375, 0.0051190476190476, 0.0132499999999999, 0.031935483870967 ...
# Unique DailyPresentWeatherType: ['-SH:6 SN:03 |SHSN |SHSN', 'TS:7 RA:02 BR:1 |RA TS |RA', 'VCTS:7 ||', 'VCFG:2 ||FG s', 'FU:3 HZ:7 |HZ FU |FU HZ', '|FG |', 'DZ:01 |DZ |DZ', '-SG:04 ||', '* |* |*', '|HZ |', 'FU:3 |FU |FU', '+SN:03 FZ:8 FG:2 |FG SN |', 'FZ:8 RA:02 |FZRA |', '|HZ FU |', '-FZ:8 RA:02 |FZRA |', 'HZ:7 s FU:3 s |HZ FU s |FU s HZ s', '|TS |', '|DZ |RA', 'PL:06 |PL |PL', '+SN:03 |SN s |', 'SN:03 |SN |', '-SN:03 RA:02 |RA RA SN |RA', 'DU:5 |HZ |FU', '-RA:02 BR:1 |s RA s |RA s', 'VCFG:2 s ||FG s', '|TS |RA', 'BC:3 FG:2 |FG |', 'VCTS:7 HZ:7 |FU |HZ', 'FU:3 BR:1 |HZ FU |FU', 'HZ:7 BL:5 DU:5 |FU |HZ', '+RA:02 |RA |RA', 'BL:5 DU:5 SQ:2 |SQ |', '-RA:02 GS:08 |RA |RA PL', 'SQ:2 |SQ |', '|SHRA |', '-RA:02 BR:1 |RA |RA', '-RA:02 FU:3 |HZ FU RA |FU RA', '-FZ:8 RA:02 BR:1 |FZRA |', '||HZ', 'BL:5 SN:03 ||', '-FZ:8 DZ:01 |FZDZ |', 'FU:3 s |HZ FU s |FU s', '|SN |', '||RA', 'FZ:8 FG:2 s |FG s |', 'HZ:7 |FU |', 'FZ:8 FG:2 |FG |', '|RA |DZ', '-SN:03 |SN |', '-SN:03 FG:2 |FG SN |', 'SN:03 FZ:8 FG:2 |FG SN |', 'FU:3 |HZ FU |FU', 'TS:7 +RA:02 |RA TS TS |RA', 'HZ:7 ||HZ', 'RA:02 |RA |RA', '-DZ:01 BR:1 |s DZ s |DZ s', '|DZ |', '-DZ:01 |DZ |DZ', '-RA:02 |RA |RA', '||FG', '-RA:02 SN:03 BR:1 |s RA s RA |RA s s', 'TS:7 -RA:02 |RA TS TS |RA', 'FG:2 FU:3 |HZ FU FG |FU', '+RA:02 BR:1 |RA |RA', 'HZ:7 FU:3 |HZ FU |FU HZ', '-SN:03 BR:1 |SN |', '-FZ:8 DZ:01 BR:1 |FZDZ |', '|HZ FU |FU', 'UP:09 ||', '-RA:02 HZ:7 |RA |HZ RA', '-SN:03 BR:1 |s SN s |s', 'TS:7 HZ:7 |FU TS TS |HZ', '-SN:03 BL:5 SN:03 |SN |', 'TS:7 |TS |', 'VCTS:7 -DZ:01 |DZ |DZ', 'SN:03 FG:2 |FG SN |', 'SN:03 |SN SN |', 'DR:4 DU:5 ||', '-SN:03 |SN SN |', '-RA:02 VCTS:7 |RA |RA', 'GS:08 |HAIL |PL', 'BR:1 BC:3 FG:2 |FG |', 'VCTS:7 +RA:02 BR:1 |RA |RA', '-DZ:01 BR:1 |DZ |DZ', 'TS:7 |TS |RA', '-RA:02 SN:03 |RA RA SN |RA', 'TS:7 RA:02 |RA TS TS |RA', 'HZ:7 |SN |', '|FG FZRA |', 'BR:1 FU:3 |HZ FU |FU', '||FG s', 'SQ:2 BL:5 DU:5 |SQ |', 'BR:1 |s |', 'FG:2 |FG |', 'TS:7 +RA:02 BR:1 |RA TS |RA', 'GR:07 |HAIL |SH', '-GS:08 ||SH', 'BL:5 DU:5 ||', 'PL:06 RA:02 BR:1 |RA PL |RA PL', 'FZ:8 RA:02 FG:2 |FG FZRA |', '|RA |RA', 'BR:1 s VCFG:2 s |s |FG s', '|RA |', 'HZ:7 |FU |HZ s', 'BR:1 ||', 'TS:7 |TS TS |', 'VCTS:7 -RA:02 |RA |RA', '-RA:02 SN:03 BR:1 |RA SN |RA RA', 'FU:3 BR:1 |FU |FU', '-RA:02 s BR:1 s VCFG:2 s |s RA s |FG s RA s', '|FZDZ |', '|RA |HZ', '|FU |', 'MI:1 FG:2 |FG |', 'MI:1 FG:2 ||', '|FG SN |', 'BL:5 DU:5 s ||', 'HZ:7 FU:3 |FU |FU HZ', 'HZ:7 |FU |HZ', '-DZ:01 |DZ s |DZ s', 'BR:1 s |s |', '* |* |', '* ||', '-RA:02 SQ:2 |SQ RA |RA', 'FZ:8 RA:02 BR:1 |FZRA |', '-SH:6 RA:02 |SHRA |', 'UP:09 BR:1 ||', '-RA:02 SN:03 BR:1 |RA RA |RA', 'VCTS:7 -RA:02 BR:1 |RA |RA', '-RA:02 FG:2 |FG RA |RA', '-SN:03 FZ:8 FG:2 |FG SN |', 'RA:02 BR:1 |RA |RA', 'HZ:7 s |FU |HZ s']
# Unique DailySkyConditions: ['BKN:07 5 OVC:08 70', 'FEW:02 25 BKN:07 43 OVC:08 70', 'SCT:04 2 OVC:08 8', 'BKN:07 46 OVC:08 48', 'BKN:07 11 BKN:07 21 OVC:08 31', 'FEW:02 2 OVC:08 5', 'BKN:07 7 BKN:07 18 OVC:08 38', 'SCT:04 10 BKN:07 16 OVC:08 33', 'SCT:04 8 BKN:07 11 OVC:08 21', 'FEW:02 15 FEW:02 120 SCT:04 250', 'BKN:07 30 OVC:08 35', 'SCT:04 8 BKN:07 23 OVC:08 29', 'FEW:02 2 OVC:08 28', 'BKN:07 6 OVC:08 60', 'FEW:02 35 BKN:07 45', 'BKN:07 150 BKN:07 200', 'BKN:07 3 BKN:07 12 OVC:08 24', 'BKN:07 9 BKN:07 13 OVC:08 18', 'FEW:02 120 FEW:02 180 BKN:07 250', 'BKN:07 26 BKN:07 95', 'BKN:07 14 BKN:07 19 OVC:08 31', 'BKN:07 20 BKN:07 26 OVC:08 34', 'BKN:07 9 OVC:08 27', 'BKN:07 27 BKN:07 43', 'SCT:04 5 BKN:07 10 OVC:08 20', 'BKN:07 23 BKN:07 42 OVC:08 60', 'BKN:07 100 BKN:07 200', 'BKN:07 7 BKN:07 27 OVC:08 36', 'FEW:02 40 FEW:02 120 FEW:02 250', 'BKN:07 5 BKN:07 12 OVC:08 17', 'BKN:07 30 OVC:08 90', 'FEW:02 9 SCT:04 16 BKN:07 23', 'BKN:07 10 OVC:08 23', 'FEW:02 50 BKN:07 170', 'FEW:02 110 SCT:04 180 BKN:07 220', 'BKN:07 15 BKN:07 150', 'BKN:07 22 OVC:08 40', 'BKN:07 10 OVC:08 17', 'BKN:07 15 BKN:07 110', 'BKN:07 10 BKN:07 27 OVC:08 33', 'FEW:02 30 OVC:08 55', 'BKN:07 70 BKN:07 220', 'SCT:04 7 BKN:07 17 OVC:08 65', 'FEW:02 12 BKN:07 60 OVC:08 80', 'FEW:02 1 SCT:04 9 BKN:07 25', 'BKN:07 8 OVC:08 11', 'BKN:07 230', 'FEW:02 10 BKN:07 15', 'FEW:02 7 BKN:07 23 OVC:08 27', 'SCT:04 20 BKN:07 110', 'OVC:08 75', 'BKN:07 10 OVC:08 100', 'BKN:07 150 BKN:07 210', 'OVC:08 43', 'SCT:04 40 SCT:04 60', 'BKN:07 26 BKN:07 85', 'BKN:07 6 OVC:08 22', 'FEW:02 80 BKN:07 140 BKN:07 250', 'BKN:07 10 BKN:07 50', 'BKN:07 4 OVC:08 12', 'BKN:07 8 BKN:07 13 OVC:08 37', 'BKN:07 100 BKN:07 120 OVC:08 250', 'FEW:02 100 FEW:02 150 BKN:07 250', 'BKN:07 16 BKN:07 36 OVC:08 75', 'BKN:07 20 OVC:08 30', 'FEW:02 7 BKN:07 10 OVC:08 25', 'SCT:04 21 OVC:08 50', 'BKN:07 10 BKN:07 14 OVC:08 20', 'SCT:04 120 SCT:04 180', 'BKN:07 20 BKN:07 55 OVC:08 70', 'OVC:08 29', 'FEW:02 20 BKN:07 40 OVC:08 60', 'BKN:07 28 BKN:07 34 BKN:07 55', 'OVC:08 130', 'BKN:07 24 BKN:07 60', 'FEW:02 30 SCT:04 250', 'BKN:07 35 BKN:07 50', 'BKN:07 27 BKN:07 35', 'BKN:07 80', 'BKN:07 9 OVC:08 38', 'BKN:07 19 OVC:08 60', 'BKN:07 65', 'FEW:02 27 BKN:07 34 OVC:08 44', 'BKN:07 32 OVC:08 43', 'FEW:02 7 OVC:08 11', 'FEW:02 50 FEW:02 200', 'BKN:07 2 OVC:08 35', 'FEW:02 18 OVC:08 30', 'BKN:07 3 OVC:08 80', 'OVC:08 11', 'FEW:02 10 BKN:07 22 OVC:08 27', 'SCT:04 5', 'FEW:02 9 BKN:07 80', 'BKN:07 27 BKN:07 39 OVC:08 100', 'BKN:07 18 OVC:08 190', 'BKN:07 14 OVC:08 49', 'SCT:04 20 BKN:07 41 BKN:07 60', 'FEW:02 4 OVC:08 16', 'BKN:07 140 BKN:07 170 OVC:08 200', 'FEW:02 7 OVC:08 60', 'BKN:07 14 OVC:08 55', 'BKN:07 17 BKN:07 24 OVC:08 31', 'FEW:02 24 BKN:07 34 OVC:08 42', 'BKN:07 3 BKN:07 10 OVC:08 15', 'FEW:02 110 FEW:02 160 BKN:07 250', 'BKN:07 24 OVC:08 32', 'BKN:07 55', 'BKN:07 19 OVC:08 55', 'BKN:07 24 OVC:08 33', 'BKN:07 12 OVC:08 35', 'BKN:07 9 OVC:08 23', 'BKN:07 16 OVC:08 65', 'BKN:07 25 BKN:07 32', 'BKN:07 2 OVC:08 60', 'SCT:04 100 BKN:07 250', 'SCT:04 60 SCT:04 250', 'SCT:04 60 BKN:07 75 OVC:08 90', 'FEW:02 2 OVC:08 10', 'SCT:04 9 OVC:08 29', 'BKN:07 11 OVC:08 30', 'BKN:07 5 BKN:07 22 OVC:08 29', 'BKN:07 23 OVC:08 38', 'SCT:04 6 BKN:07 28 OVC:08 65', 'BKN:07 12 BKN:07 70', 'BKN:07 14 BKN:07 25 OVC:08 35', 'FEW:02 3 BKN:07 23 OVC:08 47', 'BKN:07 26 BKN:07 41 OVC:08 70', 'SCT:04 5 OVC:08 16', 'BKN:07 6 OVC:08 11', 'BKN:07 30 BKN:07 40 OVC:08 160', 'FEW:02 6 OVC:08 17', 'SCT:04 27', 'FEW:02 120 SCT:04 150 BKN:07 220', 'BKN:07 12 OVC:08 60', 'BKN:07 23 OVC:08 36', 'BKN:07 9 OVC:08 65', 'FEW:02 4 OVC:08 18', 'SCT:04 180 BKN:07 250', 'FEW:02 90 BKN:07 250', 'BKN:07 17 OVC:08 45', 'OVC:08 80', 'BKN:07 11 BKN:07 65 OVC:08 85', 'BKN:07 20 BKN:07 50', 'BKN:07 28 OVC:08 60', 'BKN:07 37 BKN:07 45', 'SCT:04 25 SCT:04 50 BKN:07 200', 'BKN:07 30 OVC:08 46', 'BKN:07 25 OVC:08 32', 'BKN:07 4 OVC:08 47', 'FEW:02 100 FEW:02 250', 'BKN:07 29 BKN:07 39 OVC:08 46', 'FEW:02 20 BKN:07 110 BKN:07 250', 'BKN:07 6 BKN:07 25 BKN:07 60', 'FE ...
# Unique DailyWindDirection: ['350', 0, 10, '010', 20, '50', 30, '100', 40, 50, '040', '110', 60, 70, 80, 90, '300', '320', 100, '20', 110, '250', 120, '130', 130, '030', 140, '0', '220', 150, 160, '80', '160', '330', 170, '10', 180, 190, '280', 'VRB', 200, '90', '310', 210, 220, 230, '050', '340', '060', 240, 250, '180', '360', 260, '270', '080', 270, 280, 290, '60', 300, 310, 320, '230', '200', 330, 340, 350, '210', 360, '190', '150', '30', '40', '000', '140', '070', '70', '020', '120', '170', '290', '090', '240', '260']

# %%
import numpy as np

def convert_to_radians(value):
    try:
        # Convert to int
        value_int = int(value)
        # Convert degrees to radians
        return np.deg2rad(value_int)
    except (ValueError, TypeError):
        # If conversion fails, return -1
        return -1

# Create a copy of the dictionary
ws_trim_stage_1 = {key: df.copy() for key, df in weather_stations_trim.items()}

# Apply the conversion to each dataframe in the copied dictionary
for key, df in ws_trim_stage_1.items():
    df['DailyWindDirection'] = df['DailyWindDirection'].apply(convert_to_radians)

# Verify the conversion
sample_df = ws_trim_stage_1[72790024141]
print(sample_df['DailyWindDirection'].head())
# Out:
# 0    4.188790
# 1    0.000000
# 2    0.000000
# 3    3.839724
# 4    0.174533
# Name: DailyWindDirection, dtype: float64

# %%
# Check for null values in the 'DailyPresentWeatherType' column for each dataframe
null_values = {key: df['DailyPresentWeatherType'].isnull().sum() for key, df in ws_trim_stage_1.items()}

# Display the results
display(null_values)
# Out:
# {72790024141: 0,
#  72785524114: 0,
#  72789094197: 0,
#  72793024233: 0,
#  72785794129: 0,
#  72788594266: 0,
#  72797624217: 0,
#  72785024157: 0,
#  72797094240: 0,
#  72798594276: 0,
#  72792424223: 0,
#  72792894263: 0,
#  72781024243: 0,
#  72781524237: 0,
#  72788324220: 0,
#  72698824219: 0,
#  72793894274: 0,
#  74206024207: 0,
#  72782724110: 0,
#  72793724222: 0,
#  72792594227: 0,
#  72782594239: 0,
#  72794504205: 0,
#  72792394225: 0,
#  72784524163: 0,
#  72792024227: 0,
#  72785694176: 0}

# %%
# Create a copy of ws_trim_stage_1
ws_trim_stage_2 = {key: df.copy() for key, df in ws_trim_stage_1.items()}

# # Trim the number of entries to 658
# for key in ws_trim_stage_2:
#     ws_trim_stage_2[key] = ws_trim_stage_2[key].iloc[:658]

# # Verify the trimming
# sample_df = ws_trim_stage_2[72790024141]
# print(sample_df.shape)

# Check for null values in each column for each dataframe in the trimmed dataframes
null_values_trimmed = {key: df.isnull().sum() for key, df in ws_trim_stage_2.items()}

# Display the results
for key, nulls in null_values_trimmed.items():
    print(f"Dataset {key}:")
    print(nulls)
    print()
# Out:
# Dataset 72790024141:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785524114:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72789094197:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793024233:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785794129:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788594266:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797624217:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785024157:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797094240:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72798594276:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792424223:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792894263:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781024243:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781524237:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788324220:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72698824219:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793894274:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 74206024207:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782724110:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793724222:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792594227:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782594239:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72794504205:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792394225:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72784524163:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792024227:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785694176:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64

# %%
# Create a copy of ws_trim_stage_2
ws_trim_stage_3 = {key: df.copy() for key, df in ws_trim_stage_2.items()}

# Drop dataframes that contain one or more columns with all null values
ws_trim_stage_3 = {key: df for key, df in ws_trim_stage_3.items() if not df.isnull().all(axis=0).any()}

# Verify the result
# Dictionary to store the total null elements for each dataframe
null_elements_per_df = {}

for key, df in ws_trim_stage_3.items():
    print(f"Dataset {key}:", df.isnull().sum().sum())
    print(df.isnull().sum())
    print()
# Out:
# Dataset 72790024141: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785524114: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72789094197: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793024233: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785794129: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788594266: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797624217: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785024157: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797094240: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72798594276: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792424223: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792894263: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781024243: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781524237: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788324220: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72698824219: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793894274: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 74206024207: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782724110: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793724222: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792594227: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782594239: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72794504205: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792394225: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72784524163: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792024227: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785694176: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64

# %%
# Iterate through each dataframe in the dictionary
for key, df in ws_trim_stage_3.items():
    # Filter rows with any null values
    null_entries = df[df.isnull().any(axis=1)]
    
    # Display the dataframe key and the null entries
    print(f"Dataset {key}:")
    display(null_entries)
    print()
# Out:
# Dataset 72790024141:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72785524114:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72789094197:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72793024233:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72785794129:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72788594266:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72797624217:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72785024157:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72797094240:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72798594276:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72792424223:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72792894263:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72781024243:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72781524237:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72788324220:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72698824219:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72793894274:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 74206024207:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72782724110:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72793724222:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72792594227:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72782594239:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72794504205:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72792394225:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72784524163:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72792024227:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72785694176:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []

# %%
# Create a copy of ws_trim_stage_3
ws_trim_stage_4 = {key: df.copy() for key, df in ws_trim_stage_3.items()}

# Remove any dataframe that contains null values
ws_trim_stage_4 = {key: df for key, df in ws_trim_stage_4.items() if not df.isnull().values.any()}

# Verify the result
for key, df in ws_trim_stage_4.items():
    print(f"Dataset {key} has no null values.")
    print(df.isnull().sum())
    print()
# Out:
# Dataset 72790024141 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785524114 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72789094197 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793024233 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785794129 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788594266 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797624217 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785024157 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797094240 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72798594276 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792424223 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792894263 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781024243 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781524237 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788324220 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72698824219 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793894274 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 74206024207 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782724110 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793724222 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792594227 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782594239 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72794504205 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792394225 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72784524163 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792024227 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785694176 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64

# %%
num_dataframes = len(ws_trim_stage_4)
print(f"There are {num_dataframes} dataframes in the dataset.")

total_entries = sum(len(df) for df in ws_trim_stage_4.values())
print(f"There are {total_entries} total entries in the dataset.")
# Out:
# There are 27 dataframes in the dataset.
# There are 47574 total entries in the dataset.

# %%
# Create a copy of ws_trim_stage_4
ws_trim_stage_5 = {key: df.copy() for key, df in ws_trim_stage_4.items()}

# Split the 'DailyPresentWeatherType' column into three separate columns
for key, df in ws_trim_stage_5.items():
    df[['AU', 'AW', 'MW']] = df['DailyPresentWeatherType'].str.split('|', expand=True)

# Verify the result
sample_df = ws_trim_stage_5[72790024141]
print(sample_df[['DailyPresentWeatherType', 'AU', 'AW', 'MW']].head())
# Out:
#   DailyPresentWeatherType       AU   AW  MW
# 0          -RA:02 |RA |RA  -RA:02   RA   RA
# 1          -RA:02 |RA |RA  -RA:02   RA   RA
# 2                 BR:1 ||    BR:1
# 3                UP:09 ||   UP:09
# 4                UP:09 ||   UP:09

# %%
# Dictionary to store the unique value counts for each dataset
unique_counts = {}

# Iterate through each dataframe in the dictionary
for key, df in ws_trim_stage_5.items():
    unique_counts[key] = {
        'AU': df['AU'].nunique(),
        'AW': df['AW'].nunique(),
        'MW': df['MW'].nunique()
    }

# Display the unique counts
for key, counts in unique_counts.items():
    print(f"Dataset {key}:")
    print(f"AU: {counts['AU']}, AW: {counts['AW']}, MW: {counts['MW']}")
    print()
# Out:
# Dataset 72790024141:
# AU: 19, AW: 10, MW: 4
#
# Dataset 72785524114:
# AU: 33, AW: 17, MW: 9
#
# Dataset 72789094197:
# AU: 22, AW: 8, MW: 4
#
# Dataset 72793024233:
# AU: 27, AW: 15, MW: 8
#
# Dataset 72785794129:
# AU: 20, AW: 9, MW: 3
#
# Dataset 72788594266:
# AU: 12, AW: 5, MW: 4
#
# Dataset 72797624217:
# AU: 25, AW: 12, MW: 8
#
# Dataset 72785024157:
# AU: 39, AW: 23, MW: 14
#
# Dataset 72797094240:
# AU: 15, AW: 5, MW: 3
#
# Dataset 72798594276:
# AU: 17, AW: 7, MW: 4
#
# Dataset 72792424223:
# AU: 16, AW: 6, MW: 3
#
# Dataset 72792894263:
# AU: 15, AW: 5, MW: 3
#
# Dataset 72781024243:
# AU: 21, AW: 9, MW: 5
#
# Dataset 72781524237:
# AU: 24, AW: 10, MW: 4
#
# Dataset 72788324220:
# AU: 18, AW: 8, MW: 4
#
# Dataset 72698824219:
# AU: 20, AW: 9, MW: 4
#
# Dataset 72793894274:
# AU: 21, AW: 8, MW: 6
#
# Dataset 74206024207:
# AU: 24, AW: 15, MW: 9
#
# Dataset 72782724110:
# AU: 30, AW: 12, MW: 7
#
# Dataset 72793724222:
# AU: 24, AW: 11, MW: 8
#
# Dataset 72792594227:
# AU: 17, AW: 6, MW: 3
#
# Dataset 72782594239:
# AU: 20, AW: 7, MW: 4
#
# Dataset 72794504205:
# AU: 15, AW: 5, MW: 3
#
# Dataset 72792394225:
# AU: 12, AW: 6, MW: 3
#
# Dataset 72784524163:
# AU: 27, AW: 13, MW: 7
#
# Dataset 72792024227:
# AU: 19, AW: 8, MW: 5
#
# Dataset 72785694176:
# AU: 26, AW: 11, MW: 6

# %%
# Create a copy of ws_trim_stage_5
ws_trim_stage_6 = {key: df.copy() for key, df in ws_trim_stage_5.items()}

# Function to perform one-hot encoding
def one_hot_encode(df, column):
    # Split the content by empty space
    split_data = df[column].str.split(expand=True)
    # Perform one-hot encoding
    one_hot_encoded = pd.get_dummies(split_data, prefix=column)
    # Drop the original column and concatenate the one-hot encoded columns
    df = df.drop(columns=[column])
    df = pd.concat([df, one_hot_encoded], axis=1)
    return df

# Apply the one-hot encoding to each dataframe in the copied dictionary
for key, df in ws_trim_stage_6.items():
    df = one_hot_encode(df, 'AU')
    df = one_hot_encode(df, 'AW')
    df = one_hot_encode(df, 'MW')
    ws_trim_stage_6[key] = df

# Verify the result
sample_df = ws_trim_stage_6[72790024141]
print(sample_df.head())
# Out:
#    DailyAltimeterSetting  DailyDewPointTemperature  DailyDryBulbTemperature  \
# 0              29.657600                 34.560000                45.200000
# 1              29.996667                 30.000000                37.848485
# 2              29.926038                 35.226415                37.320755
# 3              30.093333                 26.833333                40.791667
# 4              30.223750                 27.666667                34.750000
#
#    DailyPrecipitation DailyPresentWeatherType  DailyPressureChange  \
# 0            0.002917          -RA:02 |RA |RA            -0.023750
# 1            0.003226          -RA:02 |RA |RA            -0.027500
# 2            0.000000                 BR:1 ||             0.031429
# 3            0.000000                UP:09 ||            -0.063750
# 4            0.000625                UP:09 ||             0.007500
#
#    DailyPressureTendency  DailyRelativeHumidity  DailySeaLevelPressure  \
# 0               2.750000              67.640000              29.674583
# 1               3.750000              76.000000              30.004167
# 2               6.714286              93.075472              29.929091
# 3               2.375000              59.000000              30.115417
# 4               5.375000              76.458333              30.257500
#
#   DailySkyConditions  ...  AW_FZRA  AW_RA  AW_SN  AW_TS  AW_SN  AW_TS  AW_TS  \
# 0             CLR:00  ...    False   True  False  False  False  False  False
# 1             CLR:00  ...    False   True  False  False  False  False  False
# 2             CLR:00  ...    False  False  False  False  False  False  False
# 3             CLR:00  ...    False  False  False  False  False  False  False
# 4             CLR:00  ...    False  False  False  False  False  False  False
#
#    MW_HZ  MW_RA   MW_s
# 0  False   True  False
# 1  False   True  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False
#
# [5 rows x 48 columns]

# %%
# Collect all unique column names from all dataframes
all_columns = set()
for df in ws_trim_stage_6.values():
    all_columns.update(df.columns)

# Create a new dictionary to store the updated dataframes
ws_trim_stage_7 = {}

# Ensure each dataframe has all the collected columns, filling non-existent columns with False
for key, df in ws_trim_stage_6.items():
    # Remove duplicate columns
    df = df.loc[:, ~df.columns.duplicated()]
    # Reindex the dataframe to have all columns, filling missing columns with False
    df = df.reindex(columns=all_columns, fill_value=False)
    # Drop the 'DailyPresentWeatherType' column
    df = df.drop(columns=['DailyPresentWeatherType'])
    df = df.drop(columns=['DailySkyConditions'])
    # Move all columns that start with 'Daily' to the front
    daily_columns = [col for col in df.columns if col.startswith('Daily')]
    other_columns = [col for col in df.columns if not col.startswith('Daily')]
    df = df[daily_columns + other_columns]
    # Store the updated dataframe in the new dictionary
    ws_trim_stage_7[key] = df


# Verify the result
sample_df = ws_trim_stage_7[72790024141]
print(sample_df.head())
# Out:
#    DailyDewPointTemperature  DailyPressureTendency  DailyWindSpeed  \
# 0                 34.560000               2.750000       11.600000
# 1                 30.000000               3.750000        5.969697
# 2                 35.226415               6.714286        3.849057
# 3                 26.833333               2.375000       12.500000
# 4                 27.666667               5.375000        7.875000
#
#    DailySeaLevelPressure  DailyStationPressure  DailyRelativeHumidity  \
# 0              29.674583             28.328800              67.640000
# 1              30.004167             28.657273              76.000000
# 2              29.929091             28.586604              93.075472
# 3              30.115417             28.749167              59.000000
# 4              30.257500             28.874167              76.458333
#
#    DailyPrecipitation  DailyWetBulbTemperature  DailyAltimeterSetting  \
# 0            0.002917                40.480000              29.657600
# 1            0.003226                34.757576              29.996667
# 2            0.000000                36.528302              29.926038
# 3            0.000000                35.250000              30.093333
# 4            0.000625                32.000000              30.223750
#
#    DailyPressureChange  ...  AU_SN:03  AW_SN  AW_FG  AW_DZ  AW_HZ  MW_FG  \
# 0            -0.023750  ...     False  False  False  False  False  False
# 1            -0.027500  ...     False  False  False  False  False  False
# 2             0.031429  ...     False  False  False  False  False  False
# 3            -0.063750  ...     False  False  False  False  False  False
# 4             0.007500  ...     False  False  False  False  False  False
#
#    AW_SHSN  AU_-DZ:01  AU_HZ:7  AU_GS:08
# 0    False      False    False     False
# 1    False      False    False     False
# 2    False      False    False     False
# 3    False      False    False     False
# 4    False      False    False     False
#
# [5 rows x 70 columns]

# %%
# Iterate through each dataframe in the dictionary and print the number of columns
for key, df in ws_trim_stage_7.items():
    print(f"Dataset {key} has {df.shape[1]} columns.")
# Out:
# Dataset 72790024141 has 70 columns.
# Dataset 72785524114 has 70 columns.
# Dataset 72789094197 has 70 columns.
# Dataset 72793024233 has 70 columns.
# Dataset 72785794129 has 70 columns.
# Dataset 72788594266 has 70 columns.
# Dataset 72797624217 has 70 columns.
# Dataset 72785024157 has 70 columns.
# Dataset 72797094240 has 70 columns.
# Dataset 72798594276 has 70 columns.
# Dataset 72792424223 has 70 columns.
# Dataset 72792894263 has 70 columns.
# Dataset 72781024243 has 70 columns.
# Dataset 72781524237 has 70 columns.
# Dataset 72788324220 has 70 columns.
# Dataset 72698824219 has 70 columns.
# Dataset 72793894274 has 70 columns.
# Dataset 74206024207 has 70 columns.
# Dataset 72782724110 has 70 columns.
# Dataset 72793724222 has 70 columns.
# Dataset 72792594227 has 70 columns.
# Dataset 72782594239 has 70 columns.
# Dataset 72794504205 has 70 columns.
# Dataset 72792394225 has 70 columns.
# Dataset 72784524163 has 70 columns.
# Dataset 72792024227 has 70 columns.
# Dataset 72785694176 has 70 columns.

# %%
# Iterate through each dataframe in the dictionary
for key, df in ws_trim_stage_7.items():
    print(f"Dataset {key}:")
    
    # Count the number of null values in each dataframe
    null_count = df.isnull().sum().sum()
    print(f"Total null values: {null_count}")
    
    # Check if the dataframe contains a column whose type is not int, float, or bool
    valid_types = [np.dtype('int64'), np.dtype('float64'), np.dtype('bool')]
    invalid_types = df.dtypes[~df.dtypes.isin(valid_types)]
    if not invalid_types.empty:
        print("Columns with invalid types:")
        print(invalid_types)
    else:
        print("All columns have valid types (int, float, bool).")
    print()
# Out:
# Dataset 72790024141:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72785524114:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72789094197:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72793024233:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72785794129:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72788594266:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72797624217:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72785024157:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72797094240:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72798594276:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72792424223:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72792894263:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72781024243:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72781524237:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72788324220:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72698824219:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72793894274:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 74206024207:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72782724110:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72793724222:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72792594227:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72782594239:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72794504205:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72792394225:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72784524163:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72792024227:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72785694176:
# Total null values: 0
# All columns have valid types (int, float, bool).

# %%
def display_invalid_entries(dataframes):
    for key, df in dataframes.items():
        print(f"Dataset {key}:")
        
        # Select columns that are not of type int64, float64, or bool
        invalid_columns = df.select_dtypes(exclude=['int64', 'float64', 'bool']).columns
        
        # Display the entries with invalid types
        if not invalid_columns.empty:
            invalid_entries = df[invalid_columns]
            display(invalid_entries)
        else:
            print("All columns have valid types (int64, float64, bool).")
        print()

    # Call the function with ws_trim_stage_7
display_invalid_entries(ws_trim_stage_7)
# Out:
# Dataset 72790024141:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785524114:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72789094197:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72793024233:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785794129:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72788594266:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72797624217:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785024157:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72797094240:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72798594276:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792424223:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792894263:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72781024243:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72781524237:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72788324220:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72698824219:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72793894274:
# All columns have valid types (int64, float64, bool).
#
# Dataset 74206024207:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72782724110:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72793724222:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792594227:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72782594239:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72794504205:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792394225:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72784524163:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792024227:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785694176:
# All columns have valid types (int64, float64, bool).

# %%
# Create a copy of ws_trim_stage_7
ws_trim_stage_8 = {key: df.copy() for key, df in ws_trim_stage_7.items()}

# Function to encode 'DailyPrecipitation' values
def encode_precipitation(value):
    if value == 'T':
        return 0.05
    try:
        return float(value)
    except ValueError:
        return np.nan

# Apply the encoding to each dataframe in the copied dictionary
for key, df in ws_trim_stage_8.items():
    df['DailyPrecipitation'] = df['DailyPrecipitation'].apply(encode_precipitation).astype('float64')

# Verify the result
sample_df = ws_trim_stage_8[72790024141]
print(sample_df['DailyPrecipitation'].dtype)
# Out:
# float64

# %%
display_invalid_entries(ws_trim_stage_8)
# Out:
# Dataset 72790024141:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785524114:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72789094197:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72793024233:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785794129:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72788594266:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72797624217:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785024157:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72797094240:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72798594276:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792424223:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792894263:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72781024243:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72781524237:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72788324220:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72698824219:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72793894274:
# All columns have valid types (int64, float64, bool).
#
# Dataset 74206024207:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72782724110:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72793724222:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792594227:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72782594239:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72794504205:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792394225:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72784524163:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792024227:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785694176:
# All columns have valid types (int64, float64, bool).

# %%
# Function to convert object columns to float64
def convert_object_to_float(df):
    for col in df.select_dtypes(include=['object']).columns:
        try:
            df[col] = df[col].astype('float64')
        except ValueError:
            print(f"Error converting column: {col}")
            print(f"Unique values in column {col}: {df[col].unique()}")
            # Print the values that cause the error
            for value in df[col].unique():
                try:
                    float(value)
                except ValueError:
                    print(f"Problematic value in column {col}: {value}")
            
    return df

# Apply the conversion to each dataframe in the dictionary
for key, df in ws_trim_stage_8.items():
    ws_trim_stage_8[key] = convert_object_to_float(df)

# Verify the result
sample_df = ws_trim_stage_8[72790024141]
print(sample_df.dtypes)
# Out:
# DailyDewPointTemperature    float64
# DailyPressureTendency       float64
# DailyWindSpeed              float64
# DailySeaLevelPressure       float64
# DailyStationPressure        float64
#                              ...
# MW_FG                          bool
# AW_SHSN                        bool
# AU_-DZ:01                      bool
# AU_HZ:7                        bool
# AU_GS:08                       bool
# Length: 70, dtype: object

# %%
# Create a copy of ws_trim_stage_8
ws_trim_stage_9 = {key: df.copy() for key, df in ws_trim_stage_8.items()}

# Function to convert boolean columns to float64
def convert_bool_to_float(df):
    bool_columns = df.select_dtypes(include=['bool']).columns
    df[bool_columns] = df[bool_columns].astype('float64')
    return df

# Apply the conversion to each dataframe in the copied dictionary
for key, df in ws_trim_stage_9.items():
    ws_trim_stage_9[key] = convert_bool_to_float(df)

# Verify the result
sample_df = ws_trim_stage_9[72790024141]
print(sample_df.dtypes)
# Out:
# DailyDewPointTemperature    float64
# DailyPressureTendency       float64
# DailyWindSpeed              float64
# DailySeaLevelPressure       float64
# DailyStationPressure        float64
#                              ...
# MW_FG                       float64
# AW_SHSN                     float64
# AU_-DZ:01                   float64
# AU_HZ:7                     float64
# AU_GS:08                    float64
# Length: 70, dtype: object

# %%
# Directory to save the processed CSV files
output_directory = 'processed-final-data-2'

# Create the directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Export each dataframe to a CSV file
for key, df in ws_trim_stage_9.items():
    output_filepath = os.path.join(output_directory, f'{key}.csv')
    df.to_csv(output_filepath, index=False)

print("Dataframes have been exported successfully.")
# Out:
# Dataframes have been exported successfully.
