# %%
import os
import pandas as pd

# Directory containing the CSV files
directory = 'draft-final-data'

# Dictionary to store the DataFrames
weather_stations = {}

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        # Read the CSV file into a DataFrame
        filepath = os.path.join(directory, filename)
        df = pd.read_csv(filepath)
        
        # Store the DataFrame in the dictionary
        weather_stations[int(filename[:-4])] = df

# Display the keys of the dictionary to verify
print(weather_stations.keys())
# Out:
# dict_keys([72790024141, 72785524114, 72789094197, 72793024233, 72785794129, 72220804224, 72793494248, 72788594266, 72797624217, 72074924255, 72785024157, 72797094240, 72027294282, 72798594276, 72792424223, 74207124201, 72792894263, 72781024243, 72784624160, 72781524237, 72788324220, 72698824219, 72793894274, 74206024207, 72782724110, 72793724222, 72792594227, 72782594239, 72794504205, 72792394225, 72784524163, 72792024227, 72785694176, 72025400119])

# %%
# Pick one dataframe from the dictionary
sample_df = weather_stations[72790024141]

# Show the column names and their data types
print(sample_df.dtypes)
# Out:
# DATE                         object
# STATION                       int64
# DailyAltimeterSetting       float64
# DailyDewPointTemperature    float64
# DailyDryBulbTemperature     float64
# DailyPrecipitation           object
# DailyPresentWeatherType      object
# DailyPressureChange         float64
# DailyPressureTendency       float64
# DailyRelativeHumidity       float64
# DailySeaLevelPressure       float64
# DailySkyConditions           object
# DailyStationPressure        float64
# DailyVisibility             float64
# DailyWetBulbTemperature     float64
# DailyWindDirection           object
# DailyWindGustSpeed          float64
# DailyWindSpeed              float64
# dtype: object

# %%
# Create a copy of the dictionary
weather_stations_trim = {key: df.copy() for key, df in weather_stations.items()}

# Drop the specified columns from the copied dictionary
for key in weather_stations_trim:
    weather_stations_trim[key] = weather_stations_trim[key].drop(columns=['STATION', 'DATE'])

# Verify the columns have been dropped
sample_df = weather_stations_trim[72790024141]
print(sample_df.dtypes)
# Out:
# DailyAltimeterSetting       float64
# DailyDewPointTemperature    float64
# DailyDryBulbTemperature     float64
# DailyPrecipitation           object
# DailyPresentWeatherType      object
# DailyPressureChange         float64
# DailyPressureTendency       float64
# DailyRelativeHumidity       float64
# DailySeaLevelPressure       float64
# DailySkyConditions           object
# DailyStationPressure        float64
# DailyVisibility             float64
# DailyWetBulbTemperature     float64
# DailyWindDirection           object
# DailyWindGustSpeed          float64
# DailyWindSpeed              float64
# dtype: object

# %%
# Initialize sets to store unique values
unique_precipitation = set()
unique_weather_type = set()
unique_sky_conditions = set()
unique_wind_direction = set()

# Iterate through each dataframe in the dictionary
for key, df in weather_stations_trim.items():
    unique_precipitation.update(df['DailyPrecipitation'].unique())
    unique_weather_type.update(df['DailyPresentWeatherType'].unique())
    unique_sky_conditions.update(df['DailySkyConditions'].unique())
    unique_wind_direction.update(df['DailyWindDirection'].unique())

# Convert sets to lists for better readability
unique_precipitation = list(unique_precipitation)
unique_weather_type = list(unique_weather_type)
unique_sky_conditions = list(unique_sky_conditions)
unique_wind_direction = list(unique_wind_direction)

# Display the unique values
print("Unique DailyPrecipitation:", unique_precipitation)
print("Unique DailyPresentWeatherType:", unique_weather_type)
print("Unique DailySkyConditions:", unique_sky_conditions)
print("Unique DailyWindDirection:", unique_wind_direction)
# Out:
150', 'BKN:07 28 BKN:07 55 OVC:08 70', 'FEW:02 20 SCT:04 55 BKN:07 95', 'FEW:02 4 OVC:08 10', 'BKN:07 140 BKN:07 170 OVC:08 200', 'FEW:02 25 SCT:04 65 BKN:07 250', '15', 'BKN:07 8 BKN:07 70 BKN:07 180', 'FEW:02 60 BKN:07 100 BKN:07 150', 'BKN:07 30', 'BKN:07 27 BKN:07 38 BKN:07 55', 'BKN:07 14 BKN:07 23 OVC:08 45', 'BKN:07 13 OVC:08 48', 'SCT:04 15 BKN:07 150 BKN:07 220', 'SCT:04 5 OVC:08 16', 'FEW:02 1 OVC:08 70', 'FEW:02 17 BKN:07 41 OVC:08 70', 'SCT:04 120 BKN:07 230', 'BKN:07 27 OVC:08 90', 'BKN:07 23', 'FEW:02 28 FEW:02 40 SCT:04 90', 'BKN:07 21 OVC:08 110', 'BKN:07 32 OVC:08 42', 'BKN:07 4 BKN:07 15 OVC:08 55', 'BKN:07 25 OVC:08 70', 'BKN:07 27 BKN:07 38 OVC:08 70', 'BKN:07 9 OVC:08 65', 'BKN:07 12 OVC:08 19', 'FEW:02 29 SCT:04 250', 'FEW:02 100', 'BKN:07 6 BKN:07 21 OVC:08 36', 'FEW:02 14 SCT:04 20 BKN:07 45', 'BKN:07 100 OVC:08 120', 'FEW:02 100 FEW:02 180 SCT:04 250', 'FEW:02 29 FEW:02 100', 'BKN:07 10 BKN:07 25 BKN:07 50', 'FEW:02 5 SCT:04 250', 'BKN:07 2 OVC:08 14', 'BKN:07 2 OVC:08 65', 'BKN:07 28 BKN:07 80 OVC:08 95', 'BKN:07 45 OVC:08 55', 'FEW:02 65 BKN:07 80 BKN:07 120', 'BKN:07 37 OVC:08 46', 'FEW:02 9 BKN:07 24 OVC:08 34', 'FEW:02 60 BKN:07 250', 'BKN:07 36 BKN:07 55 BKN:07 85', 'FEW:02 15 SCT:04 25 BKN:07 40', 'BKN:07 220', 'BKN:07 13 OVC:08 18', 'SCT:04 13 BKN:07 25 BKN:07 60', 'FEW:02 6 BKN:07 20 OVC:08 33', 'OVC:08 29', 'BKN:07 55 BKN:07 80', 'BKN:07 130 OVC:08 150', 'BKN:07 19 OVC:08 33', 'FEW:02 8 OVC:08 28', 'OVC:08 30', 'BKN:07 17 OVC:08 34', 'FEW:0 ...
# Unique DailyWindDirection: [0, '230', 10, '210', '040', 20, 30, 40, '030', 50, 60, 70, '60', '120', '020', 80, '320', 90, 100, '340', '300', 110, '150', 'VRB', 120.0, '350', 130, 140, '050', '10', 150, 160, 170, '080', 180, '090', nan, 190, 200, '200', 210, '190', '160', 220, 230, '000', '90', '0', '240', 240, '260', '330', 250, '110', 260, 270, '100', '50', '010', 280, 290, '130', 300.0, '40', 310.0, 320, '30', 330, 340.0, 350, '060', 360.0, '170', '250', '80', '290', '360', '70', '140', '220', '280', '310', '270', '180', '070', '20']

# %%
import numpy as np

def convert_to_radians(value):
    try:
        # Convert to int
        value_int = int(value)
        # Convert degrees to radians
        return np.deg2rad(value_int)
    except (ValueError, TypeError):
        # If conversion fails, return -1
        return -1

# Create a copy of the dictionary
ws_trim_stage_1 = {key: df.copy() for key, df in weather_stations_trim.items()}

# Apply the conversion to each dataframe in the copied dictionary
for key, df in ws_trim_stage_1.items():
    df['DailyWindDirection'] = df['DailyWindDirection'].apply(convert_to_radians)

# Verify the conversion
sample_df = ws_trim_stage_1[72790024141]
print(sample_df['DailyWindDirection'].head())
# Out:
# 0    5.585054
# 1    6.283185
# 2    0.000000
# 3    6.283185
# 4    6.283185
# Name: DailyWindDirection, dtype: float64

# %%
# Check for null values in the 'DailyPresentWeatherType' column for each dataframe
null_values = {key: df['DailyPresentWeatherType'].isnull().sum() for key, df in ws_trim_stage_1.items()}

# Display the results
display(null_values)
# Out:
# {72790024141: 0,
#  72785524114: 0,
#  72789094197: 0,
#  72793024233: 0,
#  72785794129: 0,
#  72220804224: 0,
#  72793494248: 0,
#  72788594266: 0,
#  72797624217: 0,
#  72074924255: 0,
#  72785024157: 0,
#  72797094240: 0,
#  72027294282: 0,
#  72798594276: 0,
#  72792424223: 0,
#  74207124201: 0,
#  72792894263: 1,
#  72781024243: 0,
#  72784624160: 0,
#  72781524237: 0,
#  72788324220: 0,
#  72698824219: 7,
#  72793894274: 0,
#  74206024207: 0,
#  72782724110: 0,
#  72793724222: 0,
#  72792594227: 0,
#  72782594239: 0,
#  72794504205: 0,
#  72792394225: 0,
#  72784524163: 0,
#  72792024227: 0,
#  72785694176: 0,
#  72025400119: 0}

# %%
# Create a copy of ws_trim_stage_1
ws_trim_stage_2 = {key: df.copy() for key, df in ws_trim_stage_1.items()}

# Trim the number of entries to 658
for key in ws_trim_stage_2:
    ws_trim_stage_2[key] = ws_trim_stage_2[key].iloc[:658]

# Verify the trimming
sample_df = ws_trim_stage_2[72790024141]
print(sample_df.shape)

# Check for null values in each column for each dataframe in the trimmed dataframes
null_values_trimmed = {key: df.isnull().sum() for key, df in ws_trim_stage_2.items()}

# Display the results
for key, nulls in null_values_trimmed.items():
    print(f"Dataset {key}:")
    print(nulls)
    print()
# Out:
# (658, 16)
# Dataset 72790024141:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785524114:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72789094197:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793024233:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785794129:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72220804224:
# DailyAltimeterSetting         0
# DailyDewPointTemperature      0
# DailyDryBulbTemperature       0
# DailyPrecipitation            0
# DailyPresentWeatherType       0
# DailyPressureChange         658
# DailyPressureTendency       658
# DailyRelativeHumidity         0
# DailySeaLevelPressure       658
# DailySkyConditions            0
# DailyStationPressure          0
# DailyVisibility               0
# DailyWetBulbTemperature       0
# DailyWindDirection            0
# DailyWindGustSpeed            0
# DailyWindSpeed                0
# dtype: int64
#
# Dataset 72793494248:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788594266:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797624217:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72074924255:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785024157:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797094240:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72027294282:
# DailyAltimeterSetting         0
# DailyDewPointTemperature      0
# DailyDryBulbTemperature       0
# DailyPrecipitation            0
# DailyPresentWeatherType       0
# DailyPressureChange         658
# DailyPressureTendency       658
# DailyRelativeHumidity         0
# DailySeaLevelPressure       658
# DailySkyConditions            0
# DailyStationPressure          0
# DailyVisibility               0
# DailyWetBulbTemperature       0
# DailyWindDirection            0
# DailyWindGustSpeed            0
# DailyWindSpeed                0
# dtype: int64
#
# Dataset 72798594276:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792424223:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 74207124201:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792894263:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781024243:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72784624160:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781524237:
# DailyAltimeterSetting       62
# DailyDewPointTemperature     0
# DailyDryBulbTemperature      0
# DailyPrecipitation           0
# DailyPresentWeatherType      0
# DailyPressureChange         62
# DailyPressureTendency       62
# DailyRelativeHumidity        0
# DailySeaLevelPressure       62
# DailySkyConditions           0
# DailyStationPressure        62
# DailyVisibility              0
# DailyWetBulbTemperature      0
# DailyWindDirection           0
# DailyWindGustSpeed           0
# DailyWindSpeed               0
# dtype: int64
#
# Dataset 72788324220:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72698824219:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793894274:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 74206024207:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782724110:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793724222:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792594227:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782594239:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72794504205:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792394225:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72784524163:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792024227:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785694176:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72025400119:
# DailyAltimeterSetting         0
# DailyDewPointTemperature      0
# DailyDryBulbTemperature       0
# DailyPrecipitation          658
# DailyPresentWeatherType       0
# DailyPressureChange         658
# DailyPressureTendency       658
# DailyRelativeHumidity         0
# DailySeaLevelPressure       658
# DailySkyConditions            0
# DailyStationPressure          0
# DailyVisibility               0
# DailyWetBulbTemperature       0
# DailyWindDirection            0
# DailyWindGustSpeed            0
# DailyWindSpeed                0
# dtype: int64

# %%
# Create a copy of ws_trim_stage_2
ws_trim_stage_3 = {key: df.copy() for key, df in ws_trim_stage_2.items()}

# Drop dataframes that contain one or more columns with all null values
ws_trim_stage_3 = {key: df for key, df in ws_trim_stage_3.items() if not df.isnull().all(axis=0).any()}

# Verify the result
# Dictionary to store the total null elements for each dataframe
null_elements_per_df = {}

for key, df in ws_trim_stage_3.items():
    print(f"Dataset {key}:", df.isnull().sum().sum())
    print(df.isnull().sum())
    print()
# Out:
# Dataset 72790024141: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785524114: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72789094197: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793024233: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785794129: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793494248: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788594266: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797624217: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72074924255: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785024157: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797094240: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72798594276: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792424223: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 74207124201: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792894263: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781024243: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72784624160: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781524237: 310
# DailyAltimeterSetting       62
# DailyDewPointTemperature     0
# DailyDryBulbTemperature      0
# DailyPrecipitation           0
# DailyPresentWeatherType      0
# DailyPressureChange         62
# DailyPressureTendency       62
# DailyRelativeHumidity        0
# DailySeaLevelPressure       62
# DailySkyConditions           0
# DailyStationPressure        62
# DailyVisibility              0
# DailyWetBulbTemperature      0
# DailyWindDirection           0
# DailyWindGustSpeed           0
# DailyWindSpeed               0
# dtype: int64
#
# Dataset 72788324220: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72698824219: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793894274: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 74206024207: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782724110: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793724222: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792594227: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782594239: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72794504205: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792394225: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72784524163: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792024227: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785694176: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64

# %%
# Iterate through each dataframe in the dictionary
for key, df in ws_trim_stage_3.items():
    # Filter rows with any null values
    null_entries = df[df.isnull().any(axis=1)]
    
    # Display the dataframe key and the null entries
    print(f"Dataset {key}:")
    display(null_entries)
    print()
# Out:
# Dataset 72790024141:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72785524114:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72789094197:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72793024233:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72785794129:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72793494248:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72788594266:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72797624217:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72074924255:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72785024157:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72797094240:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72798594276:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72792424223:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 74207124201:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72792894263:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72781024243:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72784624160:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72781524237:
#      DailyAltimeterSetting  DailyDewPointTemperature  DailyDryBulbTemperature  \
# 596                    NaN                      32.0                     71.0
# 597                    NaN                      32.0                     71.0
# 598                    NaN                      32.0                     71.0
# 599                    NaN                      32.0                     71.0
# 600                    NaN                      32.0                     71.0
# ..                     ...                       ...                      ...
# 653                    NaN                      50.0                     50.0
# 654                    NaN                      34.0                     34.0
# 655                    NaN                      33.0                     33.0
# 656                    NaN                      35.0                     35.0
# 657                    NaN                      50.0                     50.0
#
#     DailyPrecipitation DailyPresentWeatherType  DailyPressureChange  \
# 596               0.02              FG:2 |FG |                  NaN
# 597               0.02              FG:2 |FG |                  NaN
# 598               0.02              FG:2 |FG |                  NaN
# 599               0.02              FG:2 |FG |                  NaN
# 600               0.02              FG:2 |FG |                  NaN
# ..                 ...                     ...                  ...
# 653               0.01       -SN:03 BR:1 |SN |                  NaN
# 654               0.01       -SN:03 BR:1 |SN |                  NaN
# 655               0.01                 BR:1 ||                  NaN
# 656               0.01     -RA:02 BR:1 |RA |RA                  NaN
# 657                  T     -RA:02 BR:1 |RA |RA                  NaN
#
#      DailyPressureTendency  DailyRelativeHumidity  DailySeaLevelPressure  \
# 596                    NaN                   17.0                    NaN
# 597                    NaN                   17.0                    NaN
# 598                    NaN                   17.0                    NaN
# 599                    NaN                   17.0                    NaN
# 600                    NaN                   17.0                    NaN
# ..                     ...                    ...                    ...
# 653                    NaN                  100.0                    NaN
# 654                    NaN                  100.0                    NaN
# 655                    NaN                  100.0                    NaN
# 656                    NaN                  100.0                    NaN
# 657                    NaN                  100.0                    NaN
#
#     DailySkyConditions  DailyStationPressure DailyVisibility  \
# 596             CLR:00                   NaN           10.00
# 597             CLR:00                   NaN           10.00
# 598             CLR:00                   NaN           10.00
# 599             CLR:00                   NaN           10.00
# 600             CLR:00                   NaN           10.00
# ..                 ...                   ...             ...
# 653           OVC:08 2                   NaN           10.00
# 654           OVC:08 3                   NaN           10.00
# 655            VV:09 2                   NaN            0.50
# 656           OVC:08 4                   NaN            0.50
# 657            VV:09 2                   NaN           10.00
#
#     DailyWetBulbTemperature  DailyWindDirection  DailyWindGustSpeed  \
# 596                       *                 0.0           18.000000
# 597                       *                 0.0           18.000000
# 598                       *                 0.0           18.000000
# 599                       *                 0.0           18.000000
# 600                       *                 0.0           18.000000
# ..                      ...                 ...                 ...
# 653                       *                 0.0           26.428571
# 654                       *                -1.0           26.428571
# 655                       *                -1.0           26.428571
# 656                       *                 0.0           26.428571
# 657                       *                -1.0           27.315789
#
#      DailyWindSpeed
# 596        3.333333
# 597        3.333333
# 598        3.333333
# 599        3.333333
# 600        3.333333
# ..              ...
# 653        1.355556
# 654        4.423729
# 655        4.232558
# 656        3.531915
# 657        5.086207
#
# [62 rows x 16 columns]
# Dataset 72788324220:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72698824219:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72793894274:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 74206024207:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72782724110:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72793724222:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72792594227:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72782594239:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72794504205:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72792394225:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72784524163:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72792024227:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []
# Dataset 72785694176:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyVisibility, DailyWetBulbTemperature, DailyWindDirection, DailyWindGustSpeed, DailyWindSpeed]
# Index: []

# %%
# Create a copy of ws_trim_stage_3
ws_trim_stage_4 = {key: df.copy() for key, df in ws_trim_stage_3.items()}

# Remove any dataframe that contains null values
ws_trim_stage_4 = {key: df for key, df in ws_trim_stage_4.items() if not df.isnull().values.any()}

# Verify the result
for key, df in ws_trim_stage_4.items():
    print(f"Dataset {key} has no null values.")
    print(df.isnull().sum())
    print()
# Out:
# Dataset 72790024141 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785524114 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72789094197 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793024233 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785794129 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793494248 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788594266 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797624217 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72074924255 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785024157 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797094240 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72798594276 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792424223 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 74207124201 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792894263 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781024243 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72784624160 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788324220 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72698824219 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793894274 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 74206024207 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782724110 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793724222 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792594227 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782594239 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72794504205 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792394225 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72784524163 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792024227 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785694176 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyVisibility             0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindGustSpeed          0
# DailyWindSpeed              0
# dtype: int64

# %%
num_dataframes = len(ws_trim_stage_4)
print(f"There are {num_dataframes} dataframes in the dataset.")

total_entries = sum(len(df) for df in ws_trim_stage_4.values())
print(f"There are {total_entries} total entries in the dataset.")
# Out:
# There are 30 dataframes in the dataset.
# There are 19740 total entries in the dataset.

# %%
# Create a copy of ws_trim_stage_4
ws_trim_stage_5 = {key: df.copy() for key, df in ws_trim_stage_4.items()}

# Split the 'DailyPresentWeatherType' column into three separate columns
for key, df in ws_trim_stage_5.items():
    df[['AU', 'AW', 'MW']] = df['DailyPresentWeatherType'].str.split('|', expand=True)

# Verify the result
sample_df = ws_trim_stage_5[72790024141]
print(sample_df[['DailyPresentWeatherType', 'AU', 'AW', 'MW']].head())
# Out:
#   DailyPresentWeatherType            AU   AW MW
# 0       -SN:03 BR:1 |SN |  -SN:03 BR:1   SN
# 1       -SN:03 BR:1 |SN |  -SN:03 BR:1   SN
# 2                 BR:1 ||         BR:1
# 3            -SN:03 |SN |       -SN:03   SN
# 4                 BR:1 ||         BR:1

# %%
# Dictionary to store the unique value counts for each dataset
unique_counts = {}

# Iterate through each dataframe in the dictionary
for key, df in ws_trim_stage_5.items():
    unique_counts[key] = {
        'AU': df['AU'].nunique(),
        'AW': df['AW'].nunique(),
        'MW': df['MW'].nunique()
    }

# Display the unique counts
for key, counts in unique_counts.items():
    print(f"Dataset {key}:")
    print(f"AU: {counts['AU']}, AW: {counts['AW']}, MW: {counts['MW']}")
    print()
# Out:
# Dataset 72790024141:
# AU: 15, AW: 8, MW: 4
#
# Dataset 72785524114:
# AU: 22, AW: 13, MW: 7
#
# Dataset 72789094197:
# AU: 17, AW: 7, MW: 4
#
# Dataset 72793024233:
# AU: 18, AW: 10, MW: 7
#
# Dataset 72785794129:
# AU: 16, AW: 7, MW: 3
#
# Dataset 72793494248:
# AU: 12, AW: 7, MW: 5
#
# Dataset 72788594266:
# AU: 9, AW: 5, MW: 3
#
# Dataset 72797624217:
# AU: 12, AW: 6, MW: 4
#
# Dataset 72074924255:
# AU: 18, AW: 10, MW: 7
#
# Dataset 72785024157:
# AU: 28, AW: 19, MW: 10
#
# Dataset 72797094240:
# AU: 9, AW: 5, MW: 3
#
# Dataset 72798594276:
# AU: 10, AW: 6, MW: 3
#
# Dataset 72792424223:
# AU: 12, AW: 6, MW: 3
#
# Dataset 74207124201:
# AU: 16, AW: 8, MW: 5
#
# Dataset 72792894263:
# AU: 13, AW: 5, MW: 3
#
# Dataset 72781024243:
# AU: 15, AW: 8, MW: 5
#
# Dataset 72784624160:
# AU: 18, AW: 8, MW: 6
#
# Dataset 72788324220:
# AU: 13, AW: 7, MW: 3
#
# Dataset 72698824219:
# AU: 17, AW: 8, MW: 3
#
# Dataset 72793894274:
# AU: 12, AW: 6, MW: 3
#
# Dataset 74206024207:
# AU: 15, AW: 11, MW: 5
#
# Dataset 72782724110:
# AU: 17, AW: 9, MW: 5
#
# Dataset 72793724222:
# AU: 16, AW: 7, MW: 6
#
# Dataset 72792594227:
# AU: 13, AW: 5, MW: 3
#
# Dataset 72782594239:
# AU: 14, AW: 7, MW: 4
#
# Dataset 72794504205:
# AU: 11, AW: 5, MW: 3
#
# Dataset 72792394225:
# AU: 10, AW: 5, MW: 3
#
# Dataset 72784524163:
# AU: 17, AW: 9, MW: 5
#
# Dataset 72792024227:
# AU: 11, AW: 5, MW: 4
#
# Dataset 72785694176:
# AU: 18, AW: 8, MW: 4

# %%
# Create a copy of ws_trim_stage_5
ws_trim_stage_6 = {key: df.copy() for key, df in ws_trim_stage_5.items()}

# Function to perform one-hot encoding
def one_hot_encode(df, column):
    # Split the content by empty space
    split_data = df[column].str.split(expand=True)
    # Perform one-hot encoding
    one_hot_encoded = pd.get_dummies(split_data, prefix=column)
    # Drop the original column and concatenate the one-hot encoded columns
    df = df.drop(columns=[column])
    df = pd.concat([df, one_hot_encoded], axis=1)
    return df

# Apply the one-hot encoding to each dataframe in the copied dictionary
for key, df in ws_trim_stage_6.items():
    df = one_hot_encode(df, 'AU')
    df = one_hot_encode(df, 'AW')
    df = one_hot_encode(df, 'MW')
    ws_trim_stage_6[key] = df

# Verify the result
sample_df = ws_trim_stage_6[72790024141]
print(sample_df.head())
# Out:
#    DailyAltimeterSetting  DailyDewPointTemperature  DailyDryBulbTemperature  \
# 0              30.094848                      26.0                28.545455
# 1              29.956389                      26.0                30.166667
# 2              29.946216                      29.0                29.918919
# 3              29.991429                      27.0                33.250000
# 4              29.757500                      28.0                36.333333
#
#   DailyPrecipitation DailyPresentWeatherType  DailyPressureChange  \
# 0                  0       -SN:03 BR:1 |SN |             -0.02125
# 1                  0       -SN:03 BR:1 |SN |              0.02875
# 2                  0                 BR:1 ||             -0.02125
# 3                  0            -SN:03 |SN |              0.02125
# 4                  0                 BR:1 ||              0.00250
#
#    DailyPressureTendency  DailyRelativeHumidity  DailySeaLevelPressure  \
# 0                  4.250              87.757576              30.141667
# 1                  6.875              83.000000              29.976667
# 2                  3.375              89.378378              29.983750
# 3                  5.875              79.142857              30.035000
# 4                  4.625              75.291667              29.785417
#
#   DailySkyConditions  ...  AW_FU  AW_FZRA  AW_RA  AW_SN  AW_TS  AW_SN  AW_TS  \
# 0          OVC:08 10  ...  False    False  False   True  False  False  False
# 1          OVC:08 15  ...  False    False  False   True  False  False  False
# 2           OVC:08 5  ...  False    False  False  False  False  False  False
# 3          OVC:08 70  ...  False    False  False   True  False  False  False
# 4             CLR:00  ...  False    False  False  False  False  False  False
#
#    MW_HZ  MW_RA   MW_s
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False
#
# [5 rows x 43 columns]

# %%
# Collect all unique column names from all dataframes
all_columns = set()
for df in ws_trim_stage_6.values():
    all_columns.update(df.columns)

# Create a new dictionary to store the updated dataframes
ws_trim_stage_7 = {}

# Ensure each dataframe has all the collected columns, filling non-existent columns with False
for key, df in ws_trim_stage_6.items():
    # Remove duplicate columns
    df = df.loc[:, ~df.columns.duplicated()]
    # Reindex the dataframe to have all columns, filling missing columns with False
    df = df.reindex(columns=all_columns, fill_value=False)
    # Drop the 'DailyPresentWeatherType' column
    df = df.drop(columns=['DailyPresentWeatherType'])
    df = df.drop(columns=['DailySkyConditions'])
    # Move all columns that start with 'Daily' to the front
    daily_columns = [col for col in df.columns if col.startswith('Daily')]
    other_columns = [col for col in df.columns if not col.startswith('Daily')]
    df = df[daily_columns + other_columns]
    # Store the updated dataframe in the new dictionary
    ws_trim_stage_7[key] = df


# Verify the result
sample_df = ws_trim_stage_7[72790024141]
print(sample_df.head())
# Out:
#    DailyPressureTendency  DailyVisibility  DailyWindSpeed  \
# 0                  4.250             10.0             5.0
# 1                  6.875             10.0             6.0
# 2                  3.375             10.0             0.0
# 3                  5.875             10.0            13.0
# 4                  4.625             10.0            10.0
#
#    DailyWetBulbTemperature  DailyDryBulbTemperature  DailyStationPressure  \
# 0                27.515152                28.545455             28.750000
# 1                28.611111                30.166667             28.616389
# 2                28.918919                29.918919             28.606486
# 3                31.000000                33.250000             28.651071
# 4                33.541667                36.333333             28.426250
#
#    DailyAltimeterSetting  DailyWindDirection  DailyRelativeHumidity  \
# 0              30.094848            5.585054              87.757576
# 1              29.956389            6.283185              83.000000
# 2              29.946216            0.000000              89.378378
# 3              29.991429            6.283185              79.142857
# 4              29.757500            6.283185              75.291667
#
#    DailySeaLevelPressure  ...  AU_FZ:8 AU_VCTS:7  AU_TS:7  AU_HZ:7  MW_RA  \
# 0              30.141667  ...    False     False    False    False  False
# 1              29.976667  ...    False     False    False    False  False
# 2              29.983750  ...    False     False    False    False  False
# 3              30.035000  ...    False     False    False    False  False
# 4              29.785417  ...    False     False    False    False  False
#
#    AU_-RA:02  AW_FU  MW_DZ   MW_*   AU_s
# 0      False  False  False  False  False
# 1      False  False  False  False  False
# 2      False  False  False  False  False
# 3      False  False  False  False  False
# 4      False  False  False  False  False
#
# [5 rows x 64 columns]

# %%
# Iterate through each dataframe in the dictionary and print the number of columns
for key, df in ws_trim_stage_7.items():
    print(f"Dataset {key} has {df.shape[1]} columns.")
# Out:
# Dataset 72790024141 has 64 columns.
# Dataset 72785524114 has 64 columns.
# Dataset 72789094197 has 64 columns.
# Dataset 72793024233 has 64 columns.
# Dataset 72785794129 has 64 columns.
# Dataset 72793494248 has 64 columns.
# Dataset 72788594266 has 64 columns.
# Dataset 72797624217 has 64 columns.
# Dataset 72074924255 has 64 columns.
# Dataset 72785024157 has 64 columns.
# Dataset 72797094240 has 64 columns.
# Dataset 72798594276 has 64 columns.
# Dataset 72792424223 has 64 columns.
# Dataset 74207124201 has 64 columns.
# Dataset 72792894263 has 64 columns.
# Dataset 72781024243 has 64 columns.
# Dataset 72784624160 has 64 columns.
# Dataset 72788324220 has 64 columns.
# Dataset 72698824219 has 64 columns.
# Dataset 72793894274 has 64 columns.
# Dataset 74206024207 has 64 columns.
# Dataset 72782724110 has 64 columns.
# Dataset 72793724222 has 64 columns.
# Dataset 72792594227 has 64 columns.
# Dataset 72782594239 has 64 columns.
# Dataset 72794504205 has 64 columns.
# Dataset 72792394225 has 64 columns.
# Dataset 72784524163 has 64 columns.
# Dataset 72792024227 has 64 columns.
# Dataset 72785694176 has 64 columns.

# %%
# Iterate through each dataframe in the dictionary
for key, df in ws_trim_stage_7.items():
    print(f"Dataset {key}:")
    
    # Count the number of null values in each dataframe
    null_count = df.isnull().sum().sum()
    print(f"Total null values: {null_count}")
    
    # Check if the dataframe contains a column whose type is not int, float, or bool
    valid_types = [np.dtype('int64'), np.dtype('float64'), np.dtype('bool')]
    invalid_types = df.dtypes[~df.dtypes.isin(valid_types)]
    if not invalid_types.empty:
        print("Columns with invalid types:")
        print(invalid_types)
    else:
        print("All columns have valid types (int, float, bool).")
    print()
# Out:
# Dataset 72790024141:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72785524114:
# Total null values: 0
# Columns with invalid types:
# DailyVisibility       object
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72789094197:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72793024233:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72785794129:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72793494248:
# Total null values: 0
# Columns with invalid types:
# DailyWetBulbTemperature     object
# DailyDryBulbTemperature     object
# DailyRelativeHumidity       object
# DailyPrecipitation          object
# DailyDewPointTemperature    object
# dtype: object
#
# Dataset 72788594266:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72797624217:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72074924255:
# Total null values: 0
# Columns with invalid types:
# DailyVisibility       object
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72785024157:
# Total null values: 0
# Columns with invalid types:
# DailyVisibility       object
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72797094240:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72798594276:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72792424223:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 74207124201:
# Total null values: 0
# Columns with invalid types:
# DailyVisibility       object
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72792894263:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72781024243:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72784624160:
# Total null values: 0
# Columns with invalid types:
# DailyWetBulbTemperature     object
# DailyDryBulbTemperature     object
# DailyRelativeHumidity       object
# DailyPrecipitation          object
# DailyDewPointTemperature    object
# dtype: object
#
# Dataset 72788324220:
# Total null values: 0
# Columns with invalid types:
# DailyVisibility       object
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72698824219:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72793894274:
# Total null values: 0
# Columns with invalid types:
# DailyWetBulbTemperature    object
# DailyDryBulbTemperature    object
# DailyPrecipitation         object
# dtype: object
#
# Dataset 74206024207:
# Total null values: 0
# Columns with invalid types:
# DailyVisibility       object
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72782724110:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72793724222:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72792594227:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72782594239:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72794504205:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72792394225:
# Total null values: 0
# Columns with invalid types:
# DailyDryBulbTemperature     object
# DailyStationPressure        object
# DailyAltimeterSetting       object
# DailyPrecipitation          object
# DailyDewPointTemperature    object
# dtype: object
#
# Dataset 72784524163:
# Total null values: 0
# Columns with invalid types:
# DailyWindGustSpeed    object
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72792024227:
# Total null values: 0
# Columns with invalid types:
# DailyPrecipitation    object
# dtype: object
#
# Dataset 72785694176:
# Total null values: 0
# Columns with invalid types:
# DailyWindGustSpeed    object
# DailyPrecipitation    object
# dtype: object

# %%
def display_invalid_entries(dataframes):
    for key, df in dataframes.items():
        print(f"Dataset {key}:")
        
        # Select columns that are not of type int64, float64, or bool
        invalid_columns = df.select_dtypes(exclude=['int64', 'float64', 'bool']).columns
        
        # Display the entries with invalid types
        if not invalid_columns.empty:
            invalid_entries = df[invalid_columns]
            display(invalid_entries)
        else:
            print("All columns have valid types (int64, float64, bool).")
        print()

    # Call the function with ws_trim_stage_7
    display_invalid_entries(ws_trim_stage_7)
# Out:
# Dataset 72790024141:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656               0.00
# 657               0.00
#
# [658 rows x 1 columns]
# Dataset 72785524114:
#     DailyVisibility DailyPrecipitation
# 0                10                  T
# 1                10                  T
# 2                10                  T
# 3                10                  T
# 4                10                  T
# ..              ...                ...
# 653           10.00                  T
# 654           10.00                  T
# 655           10.00                  T
# 656           10.00                  T
# 657           10.00                  T
#
# [658 rows x 2 columns]
# Dataset 72789094197:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656               0.00
# 657               0.00
#
# [658 rows x 1 columns]
# Dataset 72793024233:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656               0.00
# 657               0.00
#
# [658 rows x 1 columns]
# Dataset 72785794129:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656               0.00
# 657               0.00
#
# [658 rows x 1 columns]
# Dataset 72793494248:
#     DailyWetBulbTemperature DailyDryBulbTemperature DailyRelativeHumidity  \
# 0                      44.0                    45.0                  93.0
# 1                      35.0                    35.0                  96.0
# 2                      37.0                    41.0                  73.0
# 3                      42.0                    52.0                  43.0
# 4                      44.0                    54.0                  42.0
# ..                      ...                     ...                   ...
# 653                      56                      60                    72
# 654                      52                      54                    87
# 655                      46                      49                    83
# 656                      49                      52                    93
# 657                      59                      60                    93
#
#     DailyPrecipitation DailyDewPointTemperature
# 0                    0                     42.0
# 1                    0                     34.0
# 2                    0                     33.0
# 3                    0                     29.0
# 4                    0                     31.0
# ..                 ...                      ...
# 653               0.00                       50
# 654               0.00                       51
# 655               0.00                       42
# 656               0.00                       45
# 657               0.00                       58
#
# [658 rows x 5 columns]
# Dataset 72788594266:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656                  T
# 657               0.01
#
# [658 rows x 1 columns]
# Dataset 72797624217:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656               0.00
# 657               0.01
#
# [658 rows x 1 columns]
# Dataset 72074924255:
#     DailyVisibility DailyPrecipitation
# 0                10                  T
# 1                10                  T
# 2                10                  T
# 3                10                  T
# 4                10                  T
# ..              ...                ...
# 653           10.00                  T
# 654           10.00                  T
# 655           10.00                  T
# 656           10.00                  T
# 657           10.00                  T
#
# [658 rows x 2 columns]
# Dataset 72785024157:
#     DailyVisibility DailyPrecipitation
# 0                10                  0
# 1                10                  0
# 2                10                  0
# 3                10                  0
# 4                10                  0
# ..              ...                ...
# 653            10.0               0.00
# 654            10.0               0.00
# 655            10.0               0.00
# 656            10.0               0.00
# 657            10.0               0.00
#
# [658 rows x 2 columns]
# Dataset 72797094240:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                 0.01
# 3                    0
# 4                    T
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656               0.02
# 657               0.02
#
# [658 rows x 1 columns]
# Dataset 72798594276:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656               0.00
# 657               0.01
#
# [658 rows x 1 columns]
# Dataset 72792424223:
#     DailyPrecipitation
# 0                    T
# 1                    T
# 2                    T
# 3                    T
# 4                    T
# ..                 ...
# 653               0.01
# 654               0.02
# 655               0.01
# 656                  T
# 657                  T
#
# [658 rows x 1 columns]
# Dataset 74207124201:
#     DailyVisibility DailyPrecipitation
# 0                10                  T
# 1                10                  T
# 2                10                  T
# 3                10                  T
# 4                10               0.01
# ..              ...                ...
# 653           10.00                  T
# 654           10.00                  T
# 655           10.00               0.02
# 656           10.00               0.01
# 657           10.00                  T
#
# [658 rows x 2 columns]
# Dataset 72792894263:
#     DailyPrecipitation
# 0                 0.01
# 1                 0.01
# 2                 0.01
# 3                 0.01
# 4                 0.01
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656               0.00
# 657               0.00
#
# [658 rows x 1 columns]
# Dataset 72781024243:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                    0
# 3                    T
# 4                    0
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656               0.00
# 657               0.00
#
# [658 rows x 1 columns]
# Dataset 72784624160:
#     DailyWetBulbTemperature DailyDryBulbTemperature DailyRelativeHumidity  \
# 0                        31                      31                    96
# 1                        29                      30                    96
# 2                        29                      30                    92
# 3                        29                      29                    96
# 4                        31                      31                    96
# ..                      ...                     ...                   ...
# 653                      59                      71                    58
# 654                      53                      55                    87
# 655                      43                      48                    68
# 656                      45                      43                    47
# 657                      54                      54                    51
#
#     DailyPrecipitation DailyDewPointTemperature
# 0                    0                       30
# 1                    0                       28
# 2                    0                       28
# 3                    0                       28
# 4                    0                       30
# ..                 ...                      ...
# 653               0.00                       49
# 654               0.00                       51
# 655               0.00                       38
# 656               0.00                       33
# 657               0.00                       46
#
# [658 rows x 5 columns]
# Dataset 72788324220:
#     DailyVisibility DailyPrecipitation
# 0             0.25s                  0
# 1                 3                  0
# 2                 3                  0
# 3                10                  0
# 4                10                  0
# ..              ...                ...
# 653           10.00               0.00
# 654           10.00                  T
# 655           10.00                  T
# 656           10.00               0.00
# 657           10.00               0.00
#
# [658 rows x 2 columns]
# Dataset 72698824219:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656               0.00
# 657               0.00
#
# [658 rows x 1 columns]
# Dataset 72793894274:
#     DailyWetBulbTemperature DailyDryBulbTemperature DailyPrecipitation
# 0                      42.0                      43                  0
# 1                      35.0                      36                  0
# 2                      37.0                      38                  0
# 3                      41.0                      38                  0
# 4                      48.0                      49                  0
# ..                      ...                     ...                ...
# 653                      53                      54                  T
# 654                      53                      54               0.00
# 655                      46                      48               0.00
# 656                      50                      54               0.00
# 657                      59                      64               0.00
#
# [658 rows x 3 columns]
# Dataset 74206024207:
#     DailyVisibility DailyPrecipitation
# 0                10                  T
# 1                10                  T
# 2                10                  T
# 3                10                  T
# 4                10               0.01
# ..              ...                ...
# 653           10.00               0.01
# 654           10.00                  T
# 655           10.00                  T
# 656           10.00                  T
# 657           10.00                  T
#
# [658 rows x 2 columns]
# Dataset 72782724110:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656               0.00
# 657               0.00
#
# [658 rows x 1 columns]
# Dataset 72793724222:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    T
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656               0.00
# 657               0.00
#
# [658 rows x 1 columns]
# Dataset 72792594227:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                 0.01
# 3                    0
# 4                    0
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656               0.00
# 657                  T
#
# [658 rows x 1 columns]
# Dataset 72782594239:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    T
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656               0.00
# 657               0.00
#
# [658 rows x 1 columns]
# Dataset 72794504205:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 653               0.00
# 654               0.01
# 655               0.00
# 656                  T
# 657                  T
#
# [658 rows x 1 columns]
# Dataset 72792394225:
#     DailyDryBulbTemperature DailyStationPressure DailyAltimeterSetting  \
# 0                      41.0                30.08                  30.1
# 1                      51.0                29.61                 29.63
# 2                      51.0                29.75                 29.77
# 3                      44.0                29.87                 29.89
# 4                      51.0                29.34                 29.36
# ..                      ...                  ...                   ...
# 653                    54.0                30.04                 30.06
# 654                    55.0                29.98                  30.0
# 655                    46.0                 29.9                 29.92
# 656                    51.0                30.11                 30.13
# 657                    59.0                30.05                 30.07
#
#     DailyPrecipitation DailyDewPointTemperature
# 0                    0                     37.0
# 1                    0                     36.0
# 2                    0                     39.0
# 3                    0                     41.0
# 4                    0                     46.0
# ..                 ...                      ...
# 653               0.00                     54.0
# 654               0.00                     47.0
# 655               0.00                     45.0
# 656               0.02                     48.0
# 657               0.03                     59.0
#
# [658 rows x 5 columns]
# Dataset 72784524163:
#     DailyWindGustSpeed DailyPrecipitation
# 0                   24                  0
# 1                   24                  0
# 2                   24                  0
# 3                   24                  0
# 4                   24                  0
# ..                 ...                ...
# 653               26.0               0.00
# 654               26.0               0.00
# 655               16.0               0.00
# 656               23.0               0.00
# 657               22.0               0.00
#
# [658 rows x 2 columns]
# Dataset 72792024227:
#     DailyPrecipitation
# 0                    0
# 1                    0
# 2                    T
# 3                    0
# 4                    0
# ..                 ...
# 653               0.00
# 654               0.00
# 655               0.00
# 656               0.00
# 657               0.00
#
# [658 rows x 1 columns]
# Dataset 72785694176:
#     DailyWindGustSpeed DailyPrecipitation
# 0                   20                  0
# 1                   20                  0
# 2                   20                  0
# 3                   20                  0
# 4                   20                  0
# ..                 ...                ...
# 653               20.0               0.00
# 654               20.0               0.00
# 655               20.0               0.00
# 656               20.0               0.00
# 657               17.0               0.00
#
# [658 rows x 2 columns]

# %%
# Create a copy of ws_trim_stage_7
ws_trim_stage_8 = {key: df.copy() for key, df in ws_trim_stage_7.items()}

# Function to encode 'DailyPrecipitation' values
def encode_precipitation(value):
    if value == 'T':
        return 0.05
    try:
        return float(value)
    except ValueError:
        return np.nan

# Apply the encoding to each dataframe in the copied dictionary
for key, df in ws_trim_stage_8.items():
    df['DailyPrecipitation'] = df['DailyPrecipitation'].apply(encode_precipitation).astype('float64')

# Verify the result
sample_df = ws_trim_stage_8[72790024141]
print(sample_df['DailyPrecipitation'].dtype)
# Out:
# float64
