# %%
import os
import pandas as pd

# Directory containing the CSV files
directory = 'draft-final-data-2'

# Dictionary to store the DataFrames
weather_stations = {}

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        # Read the CSV file into a DataFrame
        filepath = os.path.join(directory, filename)
        df = pd.read_csv(filepath)
        
        # Store the DataFrame in the dictionary
        weather_stations[int(filename[:-4])] = df

# Display the keys of the dictionary to verify
print(weather_stations.keys())
# Out:
# dict_keys([72790024141, 72785524114, 72789094197, 72793024233, 72785794129, 72788594266, 72797624217, 72785024157, 72797094240, 72798594276, 72792424223, 72792894263, 72781024243, 72781524237, 72788324220, 72698824219, 72793894274, 74206024207, 72782724110, 72793724222, 72792594227, 72782594239, 72794504205, 72792394225, 72784524163, 72792024227, 72785694176])

# %%
# Pick one dataframe from the dictionary
sample_df = weather_stations[72790024141]

# Show the column names and their data types
print(sample_df.dtypes)
# Out:
# DATE                         object
# STATION                       int64
# DailyAltimeterSetting       float64
# DailyDewPointTemperature    float64
# DailyDryBulbTemperature     float64
# DailyPrecipitation          float64
# DailyPresentWeatherType      object
# DailyPressureChange         float64
# DailyPressureTendency       float64
# DailyRelativeHumidity       float64
# DailySeaLevelPressure       float64
# DailySkyConditions           object
# DailyStationPressure        float64
# DailyWetBulbTemperature     float64
# DailyWindDirection           object
# DailyWindSpeed              float64
# dtype: object

# %%
# Create a copy of the dictionary
weather_stations_trim = {key: df.copy() for key, df in weather_stations.items()}

# Drop the specified columns from the copied dictionary
for key in weather_stations_trim:
    weather_stations_trim[key] = weather_stations_trim[key].drop(columns=['STATION', 'DATE'])

# Verify the columns have been dropped
sample_df = weather_stations_trim[72790024141]
print(sample_df.dtypes)
# Out:
# DailyAltimeterSetting       float64
# DailyDewPointTemperature    float64
# DailyDryBulbTemperature     float64
# DailyPrecipitation          float64
# DailyPresentWeatherType      object
# DailyPressureChange         float64
# DailyPressureTendency       float64
# DailyRelativeHumidity       float64
# DailySeaLevelPressure       float64
# DailySkyConditions           object
# DailyStationPressure        float64
# DailyWetBulbTemperature     float64
# DailyWindDirection           object
# DailyWindSpeed              float64
# dtype: object

# %%
# Initialize sets to store unique values
unique_precipitation = set()
unique_weather_type = set()
unique_sky_conditions = set()
unique_wind_direction = set()

# Iterate through each dataframe in the dictionary
for key, df in weather_stations_trim.items():
    unique_precipitation.update(df['DailyPrecipitation'].unique())
    unique_weather_type.update(df['DailyPresentWeatherType'].unique())
    unique_sky_conditions.update(df['DailySkyConditions'].unique())
    unique_wind_direction.update(df['DailyWindDirection'].unique())

# Convert sets to lists for better readability
unique_precipitation = list(unique_precipitation)
unique_weather_type = list(unique_weather_type)
unique_sky_conditions = list(unique_sky_conditions)
unique_wind_direction = list(unique_wind_direction)

# Display the unique values
print("Unique DailyPrecipitation:", unique_precipitation)
print("Unique DailyPresentWeatherType:", unique_weather_type)
print("Unique DailySkyConditions:", unique_sky_conditions)
print("Unique DailyWindDirection:", unique_wind_direction)
# Out:
# Unique DailyPrecipitation: [0.0, 0.015625, 0.03125, 0.00390625, 0.0378947368421052, 0.0094736842105263, 0.0189473684210526, 0.0086666666666666, 0.0625, 0.0117647058823529, 0.0093103448275862, 0.0235483870967741, 0.0201190476190476, 0.0039583333333333, 0.0282499999999999, 0.1133333333333333, 0.0195833333333333, 0.0035185185185185, 0.0134821428571428, 0.0255813953488371, 0.0202702702702702, 0.014875, 0.0391666666666666, 0.0305, 0.0157317073170731, 0.0079166666666666, 0.0358974358974358, 0.0285714285714285, 0.0010869565217391, 0.0179761904761904, 0.0144594594594594, 0.0073809523809523, 0.0187037037037037, 0.0352272727272727, 0.0366, 0.0204651162790697, 0.0086486486486486, 0.0188333333333333, 0.0118749999999999, 0.0307692307692307, 0.0583898305084745, 0.0180263157894736, 0.0313636363636363, 0.0391935483870967, 0.015735294117647, 0.007037037037037, 0.0357446808510638, 0.0331578947368421, 0.0274242424242424, 0.0521052631578947, 0.0222222222222222, 0.0071666666666666, 0.0007471264367816, 0.0046, 0.0021739130434782, 0.0119827586206896, 0.0107, 0.0040243902439024, 0.0079032258064516, 0.0145652173913043, 0.0105555555555555, 0.0118181818181818, 0.0121153846153846, 0.0118292682926829, 0.0088461538461538, 0.005576923076923, 0.0269565217391304, 0.004090909090909, 0.0392045454545454, 0.0257407407407407, 0.0197058823529411, 0.0399137931034482, 0.0274390243902439, 0.0040322580645161, 0.0001515151515151, 0.029, 0.0063207547169811, 0.0417105263157894, 0.0056756756756756, 0.0038157894736842, 0.027560975609756, 0.0200943396226415, 0.0001612903225806, 0.0173333333333333, 0.0156521739130434, 0.0280434782608695, 0.0053448275862068, 0.0318918918918919, 0.0470454545454545, 0.0119318181818181, 0.0056666666666666, 0.0175925925925925, 0.0470967741935483, 0.0092, 0.0429824561403508, 0.0196774193548387, 0.0001960784313725, 0.0158064516129032, 0.0028947368421052, 0.09, 0.0666129032258064, 0.0123684210526315, 0.043125, 0.0369736842105263, 0.0111818181818181, 0.0275, 0.0040625, 0.011875, 0.0124444444444444, 0.0158536585365853, 0.02359375, 0.0084482758620689, 0.0236363636363636, 0.0063095238095238, 0.0006481481481481, 0.0176923076923076, 0.0253125, 0.0119354838709677, 0.0002083333333333, 0.0158333333333333, 0.0052380952380952, 0.0119696969696969, 0.0514814814814814, 0.0571428571428571, 0.0158823529411764, 0.0041176470588235, 0.08925, 0.016195652173913, 0.0074358974358974, 0.0147619047619047, 0.008030303030303, 0.0041666666666666, 0.0197916666666666, 0.0278888888888888, 0.02675, 0.0080645161290322, 0.0022413793103448, 0.0016, 0.0242857142857142, 0.0023076923076923, 0.0086607142857142, 0.0002272727272727, 0.0193518518518518, 0.0627272727272727, 0.043235294117647, 0.0171052631578947, 0.0041935483870967, 0.026578947368421, 0.0360526315789473, 0.0076315789473684, 0.0245744680851063, 0.0301724137931034, 0.0198039215686274, 0.026, 0.0172826086956521, 0.0346666666666666, 0.0394827586206896, 0.0182727272727272, 0.0024074074074074, 0.0068055555555555, 0.0143333333333333, 0.0317567567567567, 0.0146551724137931, 0.0111224489795918, 0.000340909090909, 0.0265254237288135, 0.031590909090909, 0.0532407407407407, 0.0651666666666666, 0.0198387096774193, 0.0026666666666666, 0.02525, 0.0059259259259259, 0.0143243243243243, 0.0001, 0.0067105263157894, 0.000813953488372, 0.0062, 0.0085135135135135, 0.0291304347826087, 0.0159677419354838, 0.0136792452830188, 0.0211111111111111, 0.0159848484848484, 0.0002941176470588, 0.0120588235294117, 0.0003658536585365, 0.0111538461538461, 0.0031999999999999, 0.0081818181818181, 0.008170731707317, 0.0078846153846153, 0.0094444444444444, 0.0045918367346938, 0.0225714285714285, 0.0120967741935483, 0.0042424242424242, 0.0705172413793103, 0.0253636363636363, 0.0290277777777777, 0.0128333333333333, 0.0046511627906976, 0.0003030303030303, 0.070625, 0.0011666666666666, 0.008125, 0.01203125, 0.0042647058823529, 0.01984375, 0.0113513513513513, 0.0159375, 0.02375, 0.055, 0.0296268656716417, 0.0315625, 0.0139423076923076, 0.0094339622641509, 0.00129629629629 ...
# Unique DailyPresentWeatherType: ['RA:02 BR:1 |RA |RA', '-RA:02 HZ:7 |RA |HZ RA', '-GS:08 ||SH', 'TS:7 RA:02 |RA TS TS |RA', '||FG s', 'SN:03 FZ:8 FG:2 |FG SN |', '* |* |', '-SN:03 |SN |', '|RA |DZ', '-RA:02 FG:2 |FG RA |RA', 'FU:3 HZ:7 |HZ FU |FU HZ', '|FG SN |', 'VCFG:2 ||FG s', '-RA:02 BR:1 |s RA s |RA s', '|FG |', 'BR:1 ||', '|FU |', 'BC:3 FG:2 |FG |', '||RA', '|RA |HZ', '-RA:02 SQ:2 |SQ RA |RA', '+SN:03 |SN s |', '|HZ FU |FU', 'FU:3 |HZ FU |FU', '-FZ:8 RA:02 BR:1 |FZRA |', '|HZ |', 'BR:1 |s |', '-SN:03 BR:1 |SN |', '* ||', 'GR:07 |HAIL |SH', '-FZ:8 DZ:01 |FZDZ |', 'BL:5 DU:5 ||', 'HZ:7 FU:3 |HZ FU |FU HZ', 'HZ:7 BL:5 DU:5 |FU |HZ', 'VCTS:7 -RA:02 |RA |RA', '+RA:02 |RA |RA', '|FZDZ |', '|DZ |', 'DU:5 |HZ |FU', 'HZ:7 |FU |HZ', '-RA:02 SN:03 BR:1 |RA RA |RA', '-SN:03 FG:2 |FG SN |', 'HZ:7 ||HZ', 'TS:7 -RA:02 |RA TS TS |RA', 'UP:09 ||', 'SQ:2 BL:5 DU:5 |SQ |', '-DZ:01 |DZ s |DZ s', 'VCTS:7 -DZ:01 |DZ |DZ', 'FZ:8 FG:2 |FG |', '-SN:03 BR:1 |s SN s |s', '-DZ:01 BR:1 |DZ |DZ', 'SQ:2 |SQ |', 'BL:5 DU:5 s ||', 'HZ:7 |FU |HZ s', 'TS:7 |TS |', 'FG:2 |FG |', 'HZ:7 s |FU |HZ s', 'FZ:8 RA:02 FG:2 |FG FZRA |', '|RA |', 'UP:09 BR:1 ||', 'VCTS:7 HZ:7 |FU |HZ', '* |* |*', 'VCFG:2 s ||FG s', '+RA:02 BR:1 |RA |RA', '-RA:02 |RA |RA', '-SN:03 |SN SN |', 'RA:02 |RA |RA', '|TS |', 'TS:7 +RA:02 |RA TS TS |RA', 'BR:1 s |s |', '-DZ:01 |DZ |DZ', 'BL:5 SN:03 ||', '-RA:02 SN:03 |RA RA SN |RA', '|RA |RA', 'TS:7 |TS TS |', '|SN |', 'VCTS:7 ||', '-FZ:8 RA:02 |FZRA |', '-RA:02 BR:1 |RA |RA', 'BR:1 BC:3 FG:2 |FG |', '|TS |RA', '-SN:03 FZ:8 FG:2 |FG SN |']
# Unique DailySkyConditions: ['FEW:02 20 OVC:08 45', 'BKN:07 12 OVC:08 30', 'FEW:02 120 BKN:07 250', 'SCT:04 190 BKN:07 250', 'BKN:07 17 OVC:08 70', 'BKN:07 43 BKN:07 50 OVC:08 130', 'BKN:07 8 OVC:08 19', 'FEW:02 25 BKN:07 45 OVC:08 90', 'BKN:07 3 BKN:07 9 OVC:08 13', 'BKN:07 28', 'BKN:07 12 BKN:07 35 OVC:08 65', 'SCT:04 18 SCT:04 38 BKN:07 46', 'BKN:07 16 OVC:08 37', 'BKN:07 22 OVC:08 40', 'BKN:07 19 BKN:07 44', 'FEW:02 40 FEW:02 120 SCT:04 250', 'BKN:07 19 BKN:07 24 OVC:08 42', 'FEW:02 20 SCT:04 55 BKN:07 95', 'FEW:02 13 BKN:07 29 OVC:08 46', 'BKN:07 1 OVC:08 110', 'BKN:07 2', 'BKN:07 15 OVC:08 55', 'BKN:07 7 OVC:08 14', 'FEW:02 6 OVC:08 44', 'SCT:04 40 BKN:07 85', 'VV:09 6', 'BKN:07 1 OVC:08 34', 'BKN:07 6 OVC:08 13', 'BKN:07 14 OVC:08 21', 'BKN:07 21 OVC:08 110', 'BKN:07 18 OVC:08 55', 'FEW:02 16 BKN:07 29 OVC:08 95', 'FEW:02 60 BKN:07 250', 'FEW:02 8 OVC:08 17', 'BKN:07 11 BKN:07 41 OVC:08 60', 'BKN:07 10 OVC:08 13', 'FEW:02 29 SCT:04 250', 'BKN:07 38 OVC:08 47', 'VV:09 1', 'BKN:07 3 OVC:08 70', 'BKN:07 12 OVC:08 44', 'FEW:02 4 BKN:07 39 OVC:08 50', 'BKN:07 31 OVC:08 80', 'BKN:07 13 OVC:08 18', 'BKN:07 22 OVC:08 30', 'BKN:07 3 BKN:07 7 OVC:08 30', 'BKN:07 220', 'SCT:04 170', 'FEW:02 2 BKN:07 65', 'BKN:07 21 BKN:07 60 OVC:08 75', 'BKN:07 27 OVC:08 34', '1', 'BKN:07 100 OVC:08 120', 'FEW:02 12 BKN:07 28 BKN:07 85', 'FEW:02 4 FEW:02 43 OVC:08 50', 'FEW:02 2 OVC:08 10', 'BKN:07 26 OVC:08 31', 'FEW:02 20 FEW:02 28 BKN:07 35', 'BKN:07 12 OVC:08 18', 'FEW:02 6 OVC:08 14', 'BKN:07 13 OVC:08 20', 'OVC:08 32', 'BKN:07 26 OVC:08 60', 'OVC:08 41', 'BKN:07 30 OVC:08 36', 'OVC:08 43', 'FEW:02 120 SCT:04 180', 'BKN:07 12 BKN:07 17 OVC:08 39', 'SCT:04 2 BKN:07 50 OVC:08 65', 'BKN:07 7', 'BKN:07 20 OVC:08 49', 'FEW:02 28 SCT:04 250', 'BKN:07 7 OVC:08 13', 'BKN:07 55 OVC:08 75', 'VV:09 4', 'SCT:04 40', 'FEW:02 33 SCT:04 40 BKN:07 60', 'FEW:02 90 BKN:07 250', 'BKN:07 11 OVC:08 15', 'BKN:07 16 BKN:07 36 OVC:08 75', 'BKN:07 13 OVC:08 48', 'BKN:07 110', 'FEW:02 30 OVC:08 55', 'FEW:02 110 FEW:02 250', 'BKN:07 10 OVC:08 37', 'BKN:07 13 BKN:07 34 OVC:08 100', 'BKN:07 40 OVC:08 49', 'FEW:02 50 FEW:02 100', 'FEW:02 10 BKN:07 250', 'BKN:07 50', 'FEW:02 45', 'BKN:07 5', 'BKN:07 23', 'OVC:08 1', 'FEW:02 13 BKN:07 21 OVC:08 27', 'BKN:07 5 OVC:08 8', 'BKN:07 23 OVC:08 60', 'FEW:02 150 BKN:07 250', 'BKN:07 30 BKN:07 110', 'FEW:02 19 BKN:07 28 BKN:07 44', 'FEW:02 35 SCT:04 200', 'FEW:02 13 BKN:07 23 OVC:08 34', 'FEW:02 24 BKN:07 30 OVC:08 43', 'SCT:04 90 BKN:07 130', 'BKN:07 8 OVC:08 65', 'FEW:02 9 BKN:07 24', 'BKN:07 40', 'BKN:07 2 OVC:08 21', 'OVC:08 47', 'OVC:08 85', 'OVC:08 2', 'BKN:07 1', 'FEW:02 4 BKN:07 28 OVC:08 37', 'FEW:02 50 BKN:07 80', 'SCT:04 4 SCT:04 14 OVC:08 26', 'BKN:07 10 OVC:08 31', 'FEW:02 100 BKN:07 170 BKN:07 240', 'BKN:07 10 OVC:08 47', 'BKN:07 17 BKN:07 21 OVC:08 31', 'BKN:07 5 OVC:08 15', 'BKN:07 33 OVC:08 39', 'BKN:07 11 OVC:08 110', 'FEW:02 19 OVC:08 39', 'BKN:07 10 BKN:07 27 OVC:08 33', 'BKN:07 1 BKN:07 23 BKN:07 48', 'BKN:07 14 BKN:07 29 OVC:08 34', 'BKN:07 41 OVC:08 49', 'BKN:07 9 OVC:08 15', 'OVC:08 34', 'FEW:02 9 BKN:07 14 OVC:08 60', 'FEW:02 7 OVC:08 11', 'SCT:04 7 BKN:07 28 OVC:08 40', 'OVC:08 42', 'FEW:02 100 SCT:04 250', 'FEW:02 5 BKN:07 36 OVC:08 43', 'BKN:07 27', 'SCT:04 5 SCT:04 23 OVC:08 30', 'BKN:07 10 OVC:08 20', 'SCT:04 20 OVC:08 55', 'BKN:07 12 OVC:08 29', 'FEW:02 220 BKN:07 270', 'OVC:08 300', 'FEW:02 22 SCT:04 27 BKN:07 32', 'BKN:07 23 OVC:08 50', 'FEW:02 85', 'SCT:04 28 BKN:07 35', 'BKN:07 28 BKN:07 39 OVC:08 60', 'BKN:07 21 OVC:08 49', 'BKN:07 5 OVC:08 11', 'FEW:02 32 FEW:02 85 SCT:04 120', 'FEW:02 1 OVC:08 4', 'FEW:02 9 OVC:08 90', 'BKN:07 5 BKN:07 11 OVC:08 24', 'BKN:07 21 OVC:08 45', 'BKN:07 25 OVC:08 35', 'BKN:07 8 OVC:08 23', 'SCT:04 5', 'OVC:08 240', 'BKN:07 21', 'BKN:07 11 OVC:08 60', 'FEW:02 10 BKN:07 16 OVC:08 20', 'BKN:07 8 OVC:08 13', 'BKN:07 1 BKN:07 55', 'BKN:07 3 OVC:08 9', 'BKN:07 13 BKN:07 21 OVC:08 33', 'FEW:02 20 BKN:07 40 OVC:08 60', 'BKN:07 2 OVC:08 14', 'BKN:07 5 OVC:08 37', 'FEW:02 220',  ...
# Unique DailyWindDirection: [0, '30', 10, 20, '020', 30, 40, 50, 60, '350', 70, '260', 80, '320', 90, '100', 100, '280', '110', 110, 120, 130, '210', '360', '330', 140, '300', 150, '20', '120', '180', '230', 160, '0', '010', '030', 170, 180, '190', 190, '240', 200, 210, '60', '160', 220, '70', 230, 'VRB', 240, '070', 250, '040', 260, '200', 270, '000', '290', 280, '060', 290, 300, 310, '090', 320, 330, '340', '050', 350, '250', '170', '90', '310', '40', '140', '080', '10', '130', '150', '220', '50', '80', '270']

# %%
import numpy as np

def convert_to_radians(value):
    try:
        # Convert to int
        value_int = int(value)
        # Convert degrees to radians
        return np.deg2rad(value_int)
    except (ValueError, TypeError):
        # If conversion fails, return -1
        return -1

# Create a copy of the dictionary
ws_trim_stage_1 = {key: df.copy() for key, df in weather_stations_trim.items()}

# Apply the conversion to each dataframe in the copied dictionary
for key, df in ws_trim_stage_1.items():
    df['DailyWindDirection'] = df['DailyWindDirection'].apply(convert_to_radians)

# Verify the conversion
sample_df = ws_trim_stage_1[72790024141]
print(sample_df['DailyWindDirection'].head())
# Out:
# 0    5.585054
# 1    6.283185
# 2    0.000000
# 3    6.283185
# 4    6.283185
# Name: DailyWindDirection, dtype: float64

# %%
# Check for null values in the 'DailyPresentWeatherType' column for each dataframe
null_values = {key: df['DailyPresentWeatherType'].isnull().sum() for key, df in ws_trim_stage_1.items()}

# Display the results
display(null_values)
# Out:
# {72790024141: 0,
#  72785524114: 0,
#  72789094197: 0,
#  72793024233: 0,
#  72785794129: 0,
#  72788594266: 0,
#  72797624217: 0,
#  72785024157: 0,
#  72797094240: 0,
#  72798594276: 0,
#  72792424223: 0,
#  72792894263: 0,
#  72781024243: 0,
#  72781524237: 0,
#  72788324220: 0,
#  72698824219: 0,
#  72793894274: 0,
#  74206024207: 0,
#  72782724110: 0,
#  72793724222: 0,
#  72792594227: 0,
#  72782594239: 0,
#  72794504205: 0,
#  72792394225: 0,
#  72784524163: 0,
#  72792024227: 0,
#  72785694176: 0}

# %%
# Create a copy of ws_trim_stage_1
ws_trim_stage_2 = {key: df.copy() for key, df in ws_trim_stage_1.items()}

# Trim the number of entries to 658
for key in ws_trim_stage_2:
    ws_trim_stage_2[key] = ws_trim_stage_2[key].iloc[:658]

# Verify the trimming
sample_df = ws_trim_stage_2[72790024141]
print(sample_df.shape)

# Check for null values in each column for each dataframe in the trimmed dataframes
null_values_trimmed = {key: df.isnull().sum() for key, df in ws_trim_stage_2.items()}

# Display the results
for key, nulls in null_values_trimmed.items():
    print(f"Dataset {key}:")
    print(nulls)
    print()
# Out:
# (658, 14)
# Dataset 72790024141:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785524114:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72789094197:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793024233:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785794129:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788594266:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797624217:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785024157:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797094240:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72798594276:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792424223:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792894263:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781024243:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781524237:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788324220:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72698824219:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793894274:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 74206024207:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782724110:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793724222:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792594227:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782594239:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72794504205:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792394225:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72784524163:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792024227:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785694176:
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64

# %%
# Create a copy of ws_trim_stage_2
ws_trim_stage_3 = {key: df.copy() for key, df in ws_trim_stage_2.items()}

# Drop dataframes that contain one or more columns with all null values
ws_trim_stage_3 = {key: df for key, df in ws_trim_stage_3.items() if not df.isnull().all(axis=0).any()}

# Verify the result
# Dictionary to store the total null elements for each dataframe
null_elements_per_df = {}

for key, df in ws_trim_stage_3.items():
    print(f"Dataset {key}:", df.isnull().sum().sum())
    print(df.isnull().sum())
    print()
# Out:
# Dataset 72790024141: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785524114: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72789094197: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793024233: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785794129: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788594266: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797624217: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785024157: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797094240: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72798594276: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792424223: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792894263: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781024243: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781524237: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788324220: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72698824219: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793894274: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 74206024207: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782724110: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793724222: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792594227: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782594239: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72794504205: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792394225: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72784524163: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792024227: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785694176: 0
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64

# %%
# Iterate through each dataframe in the dictionary
for key, df in ws_trim_stage_3.items():
    # Filter rows with any null values
    null_entries = df[df.isnull().any(axis=1)]
    
    # Display the dataframe key and the null entries
    print(f"Dataset {key}:")
    display(null_entries)
    print()
# Out:
# Dataset 72790024141:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72785524114:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72789094197:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72793024233:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72785794129:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72788594266:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72797624217:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72785024157:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72797094240:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72798594276:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72792424223:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72792894263:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72781024243:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72781524237:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72788324220:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72698824219:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72793894274:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 74206024207:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72782724110:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72793724222:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72792594227:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72782594239:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72794504205:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72792394225:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72784524163:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72792024227:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []
# Dataset 72785694176:
# Empty DataFrame
# Columns: [DailyAltimeterSetting, DailyDewPointTemperature, DailyDryBulbTemperature, DailyPrecipitation, DailyPresentWeatherType, DailyPressureChange, DailyPressureTendency, DailyRelativeHumidity, DailySeaLevelPressure, DailySkyConditions, DailyStationPressure, DailyWetBulbTemperature, DailyWindDirection, DailyWindSpeed]
# Index: []

# %%
# Create a copy of ws_trim_stage_3
ws_trim_stage_4 = {key: df.copy() for key, df in ws_trim_stage_3.items()}

# Remove any dataframe that contains null values
ws_trim_stage_4 = {key: df for key, df in ws_trim_stage_4.items() if not df.isnull().values.any()}

# Verify the result
for key, df in ws_trim_stage_4.items():
    print(f"Dataset {key} has no null values.")
    print(df.isnull().sum())
    print()
# Out:
# Dataset 72790024141 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785524114 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72789094197 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793024233 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785794129 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788594266 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797624217 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785024157 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72797094240 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72798594276 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792424223 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792894263 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781024243 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72781524237 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72788324220 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72698824219 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793894274 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 74206024207 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782724110 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72793724222 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792594227 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72782594239 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72794504205 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792394225 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72784524163 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72792024227 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64
#
# Dataset 72785694176 has no null values.
# DailyAltimeterSetting       0
# DailyDewPointTemperature    0
# DailyDryBulbTemperature     0
# DailyPrecipitation          0
# DailyPresentWeatherType     0
# DailyPressureChange         0
# DailyPressureTendency       0
# DailyRelativeHumidity       0
# DailySeaLevelPressure       0
# DailySkyConditions          0
# DailyStationPressure        0
# DailyWetBulbTemperature     0
# DailyWindDirection          0
# DailyWindSpeed              0
# dtype: int64

# %%
num_dataframes = len(ws_trim_stage_4)
print(f"There are {num_dataframes} dataframes in the dataset.")

total_entries = sum(len(df) for df in ws_trim_stage_4.values())
print(f"There are {total_entries} total entries in the dataset.")
# Out:
# There are 27 dataframes in the dataset.
# There are 17766 total entries in the dataset.

# %%
# Create a copy of ws_trim_stage_4
ws_trim_stage_5 = {key: df.copy() for key, df in ws_trim_stage_4.items()}

# Split the 'DailyPresentWeatherType' column into three separate columns
for key, df in ws_trim_stage_5.items():
    df[['AU', 'AW', 'MW']] = df['DailyPresentWeatherType'].str.split('|', expand=True)

# Verify the result
sample_df = ws_trim_stage_5[72790024141]
print(sample_df[['DailyPresentWeatherType', 'AU', 'AW', 'MW']].head())
# Out:
#   DailyPresentWeatherType            AU   AW MW
# 0       -SN:03 BR:1 |SN |  -SN:03 BR:1   SN
# 1       -SN:03 BR:1 |SN |  -SN:03 BR:1   SN
# 2                 BR:1 ||         BR:1
# 3            -SN:03 |SN |       -SN:03   SN
# 4                 BR:1 ||         BR:1

# %%
# Dictionary to store the unique value counts for each dataset
unique_counts = {}

# Iterate through each dataframe in the dictionary
for key, df in ws_trim_stage_5.items():
    unique_counts[key] = {
        'AU': df['AU'].nunique(),
        'AW': df['AW'].nunique(),
        'MW': df['MW'].nunique()
    }

# Display the unique counts
for key, counts in unique_counts.items():
    print(f"Dataset {key}:")
    print(f"AU: {counts['AU']}, AW: {counts['AW']}, MW: {counts['MW']}")
    print()
# Out:
# Dataset 72790024141:
# AU: 15, AW: 8, MW: 4
#
# Dataset 72785524114:
# AU: 22, AW: 13, MW: 7
#
# Dataset 72789094197:
# AU: 17, AW: 7, MW: 4
#
# Dataset 72793024233:
# AU: 18, AW: 10, MW: 7
#
# Dataset 72785794129:
# AU: 16, AW: 7, MW: 3
#
# Dataset 72788594266:
# AU: 9, AW: 5, MW: 3
#
# Dataset 72797624217:
# AU: 12, AW: 6, MW: 4
#
# Dataset 72785024157:
# AU: 28, AW: 19, MW: 10
#
# Dataset 72797094240:
# AU: 9, AW: 5, MW: 3
#
# Dataset 72798594276:
# AU: 10, AW: 6, MW: 3
#
# Dataset 72792424223:
# AU: 12, AW: 6, MW: 3
#
# Dataset 72792894263:
# AU: 13, AW: 5, MW: 3
#
# Dataset 72781024243:
# AU: 15, AW: 8, MW: 5
#
# Dataset 72781524237:
# AU: 21, AW: 10, MW: 4
#
# Dataset 72788324220:
# AU: 13, AW: 7, MW: 3
#
# Dataset 72698824219:
# AU: 17, AW: 8, MW: 3
#
# Dataset 72793894274:
# AU: 12, AW: 6, MW: 3
#
# Dataset 74206024207:
# AU: 15, AW: 11, MW: 5
#
# Dataset 72782724110:
# AU: 17, AW: 9, MW: 5
#
# Dataset 72793724222:
# AU: 16, AW: 7, MW: 6
#
# Dataset 72792594227:
# AU: 13, AW: 5, MW: 3
#
# Dataset 72782594239:
# AU: 14, AW: 7, MW: 4
#
# Dataset 72794504205:
# AU: 11, AW: 5, MW: 3
#
# Dataset 72792394225:
# AU: 10, AW: 5, MW: 3
#
# Dataset 72784524163:
# AU: 17, AW: 9, MW: 5
#
# Dataset 72792024227:
# AU: 11, AW: 5, MW: 4
#
# Dataset 72785694176:
# AU: 18, AW: 8, MW: 4

# %%
# Create a copy of ws_trim_stage_5
ws_trim_stage_6 = {key: df.copy() for key, df in ws_trim_stage_5.items()}

# Function to perform one-hot encoding
def one_hot_encode(df, column):
    # Split the content by empty space
    split_data = df[column].str.split(expand=True)
    # Perform one-hot encoding
    one_hot_encoded = pd.get_dummies(split_data, prefix=column)
    # Drop the original column and concatenate the one-hot encoded columns
    df = df.drop(columns=[column])
    df = pd.concat([df, one_hot_encoded], axis=1)
    return df

# Apply the one-hot encoding to each dataframe in the copied dictionary
for key, df in ws_trim_stage_6.items():
    df = one_hot_encode(df, 'AU')
    df = one_hot_encode(df, 'AW')
    df = one_hot_encode(df, 'MW')
    ws_trim_stage_6[key] = df

# Verify the result
sample_df = ws_trim_stage_6[72790024141]
print(sample_df.head())
# Out:
#    DailyAltimeterSetting  DailyDewPointTemperature  DailyDryBulbTemperature  \
# 0              30.094848                 25.363636                28.545455
# 1              29.956389                 25.527778                30.166667
# 2              29.946216                 27.189189                29.918919
# 3              29.991429                 27.392857                33.250000
# 4              29.757500                 29.125000                36.333333
#
#    DailyPrecipitation DailyPresentWeatherType  DailyPressureChange  \
# 0            0.000000       -SN:03 BR:1 |SN |             -0.02125
# 1            0.001111       -SN:03 BR:1 |SN |              0.02875
# 2            0.000000                 BR:1 ||             -0.02125
# 3            0.000962            -SN:03 |SN |              0.02125
# 4            0.000000                 BR:1 ||              0.00250
#
#    DailyPressureTendency  DailyRelativeHumidity  DailySeaLevelPressure  \
# 0                  4.250              87.757576              30.141667
# 1                  6.875              83.000000              29.976667
# 2                  3.375              89.378378              29.983750
# 3                  5.875              79.142857              30.035000
# 4                  4.625              75.291667              29.785417
#
#   DailySkyConditions  ...  AW_FU  AW_FZRA  AW_RA  AW_SN  AW_TS  AW_SN  AW_TS  \
# 0          OVC:08 10  ...  False    False  False   True  False  False  False
# 1          OVC:08 15  ...  False    False  False   True  False  False  False
# 2           OVC:08 5  ...  False    False  False  False  False  False  False
# 3          OVC:08 70  ...  False    False  False   True  False  False  False
# 4             CLR:00  ...  False    False  False  False  False  False  False
#
#    MW_HZ  MW_RA   MW_s
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False
#
# [5 rows x 41 columns]

# %%
# Collect all unique column names from all dataframes
all_columns = set()
for df in ws_trim_stage_6.values():
    all_columns.update(df.columns)

# Create a new dictionary to store the updated dataframes
ws_trim_stage_7 = {}

# Ensure each dataframe has all the collected columns, filling non-existent columns with False
for key, df in ws_trim_stage_6.items():
    # Remove duplicate columns
    df = df.loc[:, ~df.columns.duplicated()]
    # Reindex the dataframe to have all columns, filling missing columns with False
    df = df.reindex(columns=all_columns, fill_value=False)
    # Drop the 'DailyPresentWeatherType' column
    df = df.drop(columns=['DailyPresentWeatherType'])
    df = df.drop(columns=['DailySkyConditions'])
    # Move all columns that start with 'Daily' to the front
    daily_columns = [col for col in df.columns if col.startswith('Daily')]
    other_columns = [col for col in df.columns if not col.startswith('Daily')]
    df = df[daily_columns + other_columns]
    # Store the updated dataframe in the new dictionary
    ws_trim_stage_7[key] = df


# Verify the result
sample_df = ws_trim_stage_7[72790024141]
print(sample_df.head())
# Out:
#    DailyWindDirection  DailyDewPointTemperature  DailyStationPressure  \
# 0            5.585054                 25.363636             28.750000
# 1            6.283185                 25.527778             28.616389
# 2            0.000000                 27.189189             28.606486
# 3            6.283185                 27.392857             28.651071
# 4            6.283185                 29.125000             28.426250
#
#    DailyWindSpeed  DailyPressureTendency  DailyAltimeterSetting  \
# 0        7.454545                  4.250              30.094848
# 1        6.944444                  6.875              29.956389
# 2        1.702703                  3.375              29.946216
# 3       11.571429                  5.875              29.991429
# 4       10.583333                  4.625              29.757500
#
#    DailyWetBulbTemperature  DailyDryBulbTemperature  DailySeaLevelPressure  \
# 0                27.515152                28.545455              30.141667
# 1                28.611111                30.166667              29.976667
# 2                28.918919                29.918919              29.983750
# 3                31.000000                33.250000              30.035000
# 4                33.541667                36.333333              29.785417
#
#    DailyRelativeHumidity  ...  AU_GR:07  AU_UP:09  AU_BR:1  MW_RA   AW_s  \
# 0              87.757576  ...     False     False    False  False  False
# 1              83.000000  ...     False     False    False  False  False
# 2              89.378378  ...     False     False     True  False  False
# 3              79.142857  ...     False     False    False  False  False
# 4              75.291667  ...     False     False     True  False  False
#
#    AW_DZ  MW_HZ   AU_*  AU_HZ:7  AU_SQ:2
# 0  False  False  False    False    False
# 1  False  False  False    False    False
# 2  False  False  False    False    False
# 3  False  False  False    False    False
# 4  False  False  False    False    False
#
# [5 rows x 59 columns]

# %%
# Iterate through each dataframe in the dictionary and print the number of columns
for key, df in ws_trim_stage_7.items():
    print(f"Dataset {key} has {df.shape[1]} columns.")
# Out:
# Dataset 72790024141 has 59 columns.
# Dataset 72785524114 has 59 columns.
# Dataset 72789094197 has 59 columns.
# Dataset 72793024233 has 59 columns.
# Dataset 72785794129 has 59 columns.
# Dataset 72788594266 has 59 columns.
# Dataset 72797624217 has 59 columns.
# Dataset 72785024157 has 59 columns.
# Dataset 72797094240 has 59 columns.
# Dataset 72798594276 has 59 columns.
# Dataset 72792424223 has 59 columns.
# Dataset 72792894263 has 59 columns.
# Dataset 72781024243 has 59 columns.
# Dataset 72781524237 has 59 columns.
# Dataset 72788324220 has 59 columns.
# Dataset 72698824219 has 59 columns.
# Dataset 72793894274 has 59 columns.
# Dataset 74206024207 has 59 columns.
# Dataset 72782724110 has 59 columns.
# Dataset 72793724222 has 59 columns.
# Dataset 72792594227 has 59 columns.
# Dataset 72782594239 has 59 columns.
# Dataset 72794504205 has 59 columns.
# Dataset 72792394225 has 59 columns.
# Dataset 72784524163 has 59 columns.
# Dataset 72792024227 has 59 columns.
# Dataset 72785694176 has 59 columns.

# %%
# Iterate through each dataframe in the dictionary
for key, df in ws_trim_stage_7.items():
    print(f"Dataset {key}:")
    
    # Count the number of null values in each dataframe
    null_count = df.isnull().sum().sum()
    print(f"Total null values: {null_count}")
    
    # Check if the dataframe contains a column whose type is not int, float, or bool
    valid_types = [np.dtype('int64'), np.dtype('float64'), np.dtype('bool')]
    invalid_types = df.dtypes[~df.dtypes.isin(valid_types)]
    if not invalid_types.empty:
        print("Columns with invalid types:")
        print(invalid_types)
    else:
        print("All columns have valid types (int, float, bool).")
    print()
# Out:
# Dataset 72790024141:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72785524114:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72789094197:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72793024233:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72785794129:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72788594266:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72797624217:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72785024157:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72797094240:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72798594276:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72792424223:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72792894263:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72781024243:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72781524237:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72788324220:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72698824219:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72793894274:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 74206024207:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72782724110:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72793724222:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72792594227:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72782594239:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72794504205:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72792394225:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72784524163:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72792024227:
# Total null values: 0
# All columns have valid types (int, float, bool).
#
# Dataset 72785694176:
# Total null values: 0
# All columns have valid types (int, float, bool).

# %%
def display_invalid_entries(dataframes):
    for key, df in dataframes.items():
        print(f"Dataset {key}:")
        
        # Select columns that are not of type int64, float64, or bool
        invalid_columns = df.select_dtypes(exclude=['int64', 'float64', 'bool']).columns
        
        # Display the entries with invalid types
        if not invalid_columns.empty:
            invalid_entries = df[invalid_columns]
            display(invalid_entries)
        else:
            print("All columns have valid types (int64, float64, bool).")
        print()

    # Call the function with ws_trim_stage_7
display_invalid_entries(ws_trim_stage_7)
# Out:
# Dataset 72790024141:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785524114:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72789094197:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72793024233:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785794129:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72788594266:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72797624217:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785024157:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72797094240:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72798594276:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792424223:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792894263:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72781024243:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72781524237:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72788324220:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72698824219:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72793894274:
# All columns have valid types (int64, float64, bool).
#
# Dataset 74206024207:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72782724110:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72793724222:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792594227:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72782594239:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72794504205:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792394225:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72784524163:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792024227:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785694176:
# All columns have valid types (int64, float64, bool).

# %%
# Create a copy of ws_trim_stage_7
ws_trim_stage_8 = {key: df.copy() for key, df in ws_trim_stage_7.items()}

# Function to encode 'DailyPrecipitation' values
def encode_precipitation(value):
    if value == 'T':
        return 0.05
    try:
        return float(value)
    except ValueError:
        return np.nan

# Apply the encoding to each dataframe in the copied dictionary
for key, df in ws_trim_stage_8.items():
    df['DailyPrecipitation'] = df['DailyPrecipitation'].apply(encode_precipitation).astype('float64')

# Verify the result
sample_df = ws_trim_stage_8[72790024141]
print(sample_df['DailyPrecipitation'].dtype)
# Out:
# float64

# %%
display_invalid_entries(ws_trim_stage_8)
# Out:
# Dataset 72790024141:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785524114:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72789094197:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72793024233:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785794129:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72788594266:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72797624217:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785024157:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72797094240:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72798594276:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792424223:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792894263:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72781024243:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72781524237:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72788324220:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72698824219:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72793894274:
# All columns have valid types (int64, float64, bool).
#
# Dataset 74206024207:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72782724110:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72793724222:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792594227:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72782594239:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72794504205:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792394225:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72784524163:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72792024227:
# All columns have valid types (int64, float64, bool).
#
# Dataset 72785694176:
# All columns have valid types (int64, float64, bool).

# %%
# Function to convert object columns to float64
def convert_object_to_float(df):
    for col in df.select_dtypes(include=['object']).columns:
        try:
            df[col] = df[col].astype('float64')
        except ValueError:
            print(f"Error converting column: {col}")
            print(f"Unique values in column {col}: {df[col].unique()}")
            # Print the values that cause the error
            for value in df[col].unique():
                try:
                    float(value)
                except ValueError:
                    print(f"Problematic value in column {col}: {value}")
            
    return df

# Apply the conversion to each dataframe in the dictionary
for key, df in ws_trim_stage_8.items():
    ws_trim_stage_8[key] = convert_object_to_float(df)

# Verify the result
sample_df = ws_trim_stage_8[72790024141]
print(sample_df.dtypes)
# Out:
# DailyWindDirection          float64
# DailyDewPointTemperature    float64
# DailyStationPressure        float64
# DailyWindSpeed              float64
# DailyPressureTendency       float64
# DailyAltimeterSetting       float64
# DailyWetBulbTemperature     float64
# DailyDryBulbTemperature     float64
# DailySeaLevelPressure       float64
# DailyRelativeHumidity       float64
# DailyPressureChange         float64
# DailyPrecipitation          float64
# AW_FG                          bool
# AW_*                           bool
# AU_FG:2                        bool
# AU_FZ:8                        bool
# AW_RA                          bool
# AU_-DZ:01                      bool
# AU_+RA:02                      bool
# AU_VCFG:2                      bool
# AU_+SN:03                      bool
# AW_HAIL                        bool
# AW_SQ                          bool
# AU_-RA:02                      bool
# MW_FG                          bool
# AW_HZ                          bool
# AU_FU:3                        bool
# MW_SH                          bool
# AU_-GS:08                      bool
# AU_BC:3                        bool
# AU_-FZ:8                       bool
# AU_DU:5                        bool
# AW_SN                          bool
# AU_TS:7                        bool
# MW_DZ                          bool
# AW_FZRA                        bool
# AU_VCTS:7                      bool
# MW_FU                          bool
# AU_DZ:01                       bool
# AU_-SN:03                      bool
# AU_RA:02                       bool
# AU_BL:5                        bool
# MW_*                           bool
# AU_s                           bool
# AW_TS                          bool
# AW_FU                          bool
# MW_s                           bool
# AU_SN:03                       bool
# AW_FZDZ                        bool
# AU_GR:07                       bool
# AU_UP:09                       bool
# AU_BR:1                        bool
# MW_RA                          bool
# AW_s                           bool
# AW_DZ                          bool
# MW_HZ                          bool
# AU_*                           bool
# AU_HZ:7                        bool
# AU_SQ:2                        bool
# dtype: object

# %%
# Directory to save the processed CSV files
output_directory = 'processed-final-data'

# Create the directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Export each dataframe to a CSV file
for key, df in ws_trim_stage_8.items():
    output_filepath = os.path.join(output_directory, f'{key}.csv')
    df.to_csv(output_filepath, index=False)

print("Dataframes have been exported successfully.")
# Out:
# Dataframes have been exported successfully.
